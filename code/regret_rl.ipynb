# %%
# !pip install pandas numpy matplotlib scikit-learn scipy torch
# Out:
# Collecting pandas
#   Using cached pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting numpy
#   Using cached numpy-2.2.2-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.6.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting scipy
#   Using cached scipy-1.15.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting torch
#   Using cached torch-2.6.0-cp312-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.56.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (101 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-11.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.10.0 (from torch)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting networkx (from torch)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Using cached fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting setuptools (from torch)
#   Using cached setuptools-75.8.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting sympy==1.13.1 (from torch)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Using cached pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl (11.4 MB)
# Using cached numpy-2.2.2-cp312-cp312-macosx_14_0_arm64.whl (5.1 MB)
# Using cached matplotlib-3.10.0-cp312-cp312-macosx_11_0_arm64.whl (8.0 MB)
# Using cached scikit_learn-1.6.1-cp312-cp312-macosx_12_0_arm64.whl (11.2 MB)
# Using cached scipy-1.15.1-cp312-cp312-macosx_14_0_arm64.whl (24.9 MB)
# Using cached torch-2.6.0-cp312-none-macosx_11_0_arm64.whl (66.5 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached contourpy-1.3.1-cp312-cp312-macosx_11_0_arm64.whl (255 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.56.0-cp312-cp312-macosx_10_13_universal2.whl (2.7 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached kiwisolver-1.4.8-cp312-cp312-macosx_11_0_arm64.whl (65 kB)
# Using cached pillow-11.1.0-cp312-cp312-macosx_11_0_arm64.whl (3.1 MB)
# Using cached pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Using cached pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Using cached filelock-3.17.0-py3-none-any.whl (16 kB)
# Using cached fsspec-2025.2.0-py3-none-any.whl (184 kB)
# Using cached jinja2-3.1.5-py3-none-any.whl (134 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached setuptools-75.8.0-py3-none-any.whl (1.2 MB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-macosx_11_0_arm64.whl (12 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: pytz, mpmath, tzdata, typing-extensions, threadpoolctl, sympy, setuptools, pyparsing, pillow, numpy, networkx, MarkupSafe, kiwisolver, joblib, fsspec, fonttools, filelock, cycler, scipy, pandas, jinja2, contourpy, torch, scikit-learn, matplotlib
# Successfully installed MarkupSafe-3.0.2 contourpy-1.3.1 cycler-0.12.1 filelock-3.17.0 fonttools-4.56.0 fsspec-2025.2.0 jinja2-3.1.5 joblib-1.4.2 kiwisolver-1.4.8 matplotlib-3.10.0 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.2 pandas-2.2.3 pillow-11.1.0 pyparsing-3.2.1 pytz-2025.1 scikit-learn-1.6.1 scipy-1.15.1 setuptools-75.8.0 sympy-1.13.1 threadpoolctl-3.5.0 torch-2.6.0 typing-extensions-4.12.2 tzdata-2025.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os
from itertools import product
from sklearn.utils import resample
from scipy.stats import beta as bt
import torch
import torch.optim as optim
import torch.nn as nn
from scipy.optimize import minimize
import math
import ast

# %% [markdown]
# # Parameter fitting

# %%
df = pd.read_csv("regret_preregistered_1_for_sim.csv")
df.head()
# Out:
#    Unnamed: 0  workerid  trial_index  points  choice choice_goodbad  \
# 0           1       860            1       1       1           best
# 1           2       860            2       1       1           best
# 2           3       860            3       1       1           best
# 3           4       860            4       1       1           best
# 4           5       860            5       1       1           best
#
#      condition source  final_points  expected_value  total_expected_value
# 0  regret_late   data            31             0.7                  35.4
# 1  regret_late   data            31             0.7                  35.4
# 2  regret_late   data            31             0.7                  35.4
# 3  regret_late   data            31             0.7                  35.4
# 4  regret_late   data            31             0.7                  35.4

# %%
df = df[
        ((df['condition'] == 'regret_early') & (df['trial_index'] <= 30)) | 
        ((df['condition'] == 'regret_late') & (df['trial_index'] > 30)) |
        (df['condition'] == 'control')]

df.head()
# Out:
#     Unnamed: 0  workerid  trial_index  points  choice choice_goodbad  \
# 30          31       860           31       1       1           best
# 31          32       860           32       1       1           best
# 32          33       860           33       0       1           best
# 33          34       860           34       1       1           best
# 34          35       860           35       1       0         medium
#
#       condition source  final_points  expected_value  total_expected_value
# 30  regret_late   data            31             0.7                  35.4
# 31  regret_late   data            31             0.7                  35.4
# 32  regret_late   data            31             0.7                  35.4
# 33  regret_late   data            31             0.7                  35.4
# 34  regret_late   data            31             0.5                  35.4

# %% [markdown]
# ## GiG

# %%
# -----------------------------------------------------------------------------
# Model definition
# -----------------------------------------------------------------------------
class RegretModel(nn.Module):
    def __init__(self, condition, initial_omega=0.5, initial_tau=0.5, kappa=1.0):
        """
        If condition is 'control', omega is fixed at 0 and is not learned.
        For regret conditions ('regret_early' or 'regret_late'), omega is learnable.
        
        kappa is a fixed scaling factor used to decouple the magnitude of the omega
        from the tau.
        """
        super().__init__()
        self.condition = condition  # store the participant's condition
        self.softplus = nn.Softplus()
        self.kappa = kappa 
        
        if condition == "control":
            self.log_omega = None  # omega is fixed at 0 for control
        else:
            def softplus_inverse(x):
                return math.log(math.exp(x) - 1.0)
            init_log_omega = softplus_inverse(initial_omega)
            self.log_omega = nn.Parameter(torch.tensor(init_log_omega, dtype=torch.float32))
        
        def softplus_inverse(x):
            return math.log(math.exp(x) - 1.0)
        init_log_tau = softplus_inverse(initial_tau)
        self.log_tau = nn.Parameter(torch.tensor(init_log_tau, dtype=torch.float32))
    
    def forward(self):
        if self.condition == "control":
            omega = torch.tensor(0.0, dtype=torch.float32)
        else:
            omega = self.softplus(self.log_omega) 
        tau = self.softplus(self.log_tau) 
        return omega, tau
    
    def log_likelihood(self, participant_df):
        """
        Computes the negative log likelihood for a single participant's data.
        """
        omega, tau = self.forward()
        num_arms = 3
        
        # Initialize belief parameters for each arm (alpha and beta for Beta distributions)
        alpha = torch.ones(num_arms, dtype=torch.float32)
        #decay_factor = 1.0  
        #alpha = alpha * decay_factor  
        beta  = torch.ones(num_arms, dtype=torch.float32)
        
        df_sorted = participant_df.sort_values('trial_index')
        nll = torch.tensor(0.0, dtype=torch.float32)
        
        for _, row in df_sorted.iterrows():
            choice      = int(row['choice'])      # index of the chosen arm
            points      = int(row['points'])      # outcome: 1 (reward) or 0 (no reward)
            trial_index = int(row['trial_index'])   # trial number
            
            p_est = alpha / (alpha + beta)
            numerators = torch.exp(p_est / tau)
            probs = numerators / torch.sum(numerators)
            
            p_chosen = probs[choice]
            nll -= torch.log(p_chosen + 1e-12)  # add to negative log likelihood for numerical stability
            
            # Update beliefs for the chosen arm based on actual outcome
            if points == 1:
                alpha = alpha.clone()
                alpha[choice] += 1.0
            else:
                beta = beta.clone()
                beta[choice] += 1.0
                
                # For regret conditions, apply counterfactual updating to the non-chosen arms
                if self.condition == 'regret_early' and trial_index <= 30 and points == 0:
                    alpha = alpha.clone()  # avoid in-place modifications
                    for arm_i in range(num_arms):
                        if arm_i != choice:
                            alpha[arm_i] += self.kappa * omega
                elif self.condition == 'regret_late' and trial_index > 30 and points == 0:
                    alpha = alpha.clone()
                    for arm_i in range(num_arms):
                        if arm_i != choice:
                            alpha[arm_i] += self.kappa * omega
        
        return nll

# -----------------------------------------------------------------------------
# Training loop for each participant
# -----------------------------------------------------------------------------

unique_participants = df['workerid'].unique()

# Hyperparameters
num_epochs    = 500
learning_rate = 0.01

print_interval = 100 

all_results = [] 

for participant in unique_participants:
    participant_df = df[df['workerid'] == participant]
    participant_condition = participant_df['condition'].iloc[0]
    
    model = RegretModel(condition=participant_condition, initial_omega=0.5, initial_tau=0.5, kappa=1.0)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    
    # Training loop.
    for epoch in range(num_epochs):
        optimizer.zero_grad()
        nll = model.log_likelihood(participant_df)
        nll.backward()
        optimizer.step()
        
        if (epoch + 1) % print_interval == 0 or epoch == 0:
            with torch.no_grad():
                current_omega, current_tau = model.forward()
                print(f"Participant {participant}, Epoch {epoch+1}, NLL={nll.item():.4f}, "
                      f"omega={current_omega.item():.4f}, tau={current_tau.item():.4f}, condition={participant_condition}")
    
    with torch.no_grad():
        final_omega, final_tau = model.forward()
        final_nll = model.log_likelihood(participant_df).item()
    
    all_results.append({
        'participant': participant,
        'condition': participant_condition,
        'omega': final_omega.item(),  # check that it is 0 for control
        'tau': final_tau.item(),
        'nll': final_nll
    })

results_df = pd.DataFrame(all_results)
# Out:
# Participant 860, Epoch 1, NLL=29.8333, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 860, Epoch 100, NLL=27.6530, omega=0.2428, tau=0.2269, condition=regret_late
# Participant 860, Epoch 200, NLL=27.6140, omega=0.2314, tau=0.2090, condition=regret_late
# Participant 860, Epoch 300, NLL=27.6138, omega=0.2348, tau=0.2082, condition=regret_late
# Participant 860, Epoch 400, NLL=27.6137, omega=0.2383, tau=0.2074, condition=regret_late
# Participant 860, Epoch 500, NLL=27.6137, omega=0.2414, tau=0.2068, condition=regret_late
# Participant 835, Epoch 1, NLL=30.3529, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 835, Epoch 100, NLL=18.7586, omega=0.1949, tau=0.1691, condition=regret_late
# Participant 835, Epoch 200, NLL=4.0251, omega=0.0874, tau=0.0528, condition=regret_late
# Participant 835, Epoch 300, NLL=2.9211, omega=0.0682, tau=0.0374, condition=regret_late
# Participant 835, Epoch 400, NLL=2.7247, omega=0.0578, tau=0.0326, condition=regret_late
# Participant 835, Epoch 500, NLL=2.6326, omega=0.0496, tau=0.0301, condition=regret_late
# Participant 753, Epoch 1, NLL=33.5750, omega=0.5039, tau=0.5039, condition=regret_late
# Participant 753, Epoch 100, NLL=33.1579, omega=1.2365, tau=0.8815, condition=regret_late
# Participant 753, Epoch 200, NLL=33.0131, omega=2.2966, tau=1.1277, condition=regret_late
# Participant 753, Epoch 300, NLL=32.9506, omega=3.2042, tau=1.2610, condition=regret_late
# Participant 753, Epoch 400, NLL=32.9170, omega=3.9676, tau=1.3205, condition=regret_late
# Participant 753, Epoch 500, NLL=32.8941, omega=4.6467, tau=1.3258, condition=regret_late
# Participant 833, Epoch 1, NLL=32.4189, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 833, Epoch 100, NLL=32.3377, omega=0.2425, tau=0.4835, condition=regret_late
# Participant 833, Epoch 200, NLL=32.3236, omega=0.1659, tau=0.4797, condition=regret_late
# Participant 833, Epoch 300, NLL=32.3219, omega=0.1426, tau=0.4799, condition=regret_late
# Participant 833, Epoch 400, NLL=32.3217, omega=0.1349, tau=0.4801, condition=regret_late
# Participant 833, Epoch 500, NLL=32.3217, omega=0.1326, tau=0.4802, condition=regret_late
# Participant 841, Epoch 1, NLL=37.1960, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 841, Epoch 100, NLL=34.3933, omega=0.2316, tau=0.8793, condition=regret_late
# Participant 841, Epoch 200, NLL=33.5644, omega=0.1198, tau=1.1260, condition=regret_late
# Participant 841, Epoch 300, NLL=33.2206, omega=0.0702, tau=1.2737, condition=regret_late
# Participant 841, Epoch 400, NLL=33.0539, omega=0.0457, tau=1.3598, condition=regret_late
# Participant 841, Epoch 500, NLL=32.9624, omega=0.0321, tau=1.4058, condition=regret_late
# Participant 806, Epoch 1, NLL=28.0006, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 806, Epoch 100, NLL=26.1523, omega=0.7989, tau=0.2388, condition=regret_late
# Participant 806, Epoch 200, NLL=25.5132, omega=1.7112, tau=0.1655, condition=regret_late
# Participant 806, Epoch 300, NLL=25.3334, omega=2.4052, tau=0.1403, condition=regret_late
# Participant 806, Epoch 400, NLL=25.2649, omega=2.9084, tau=0.1274, condition=regret_late
# Participant 806, Epoch 500, NLL=25.2319, omega=3.2956, tau=0.1192, condition=regret_late
# Participant 811, Epoch 1, NLL=28.9706, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 811, Epoch 100, NLL=18.0836, omega=0.2014, tau=0.1811, condition=regret_late
# Participant 811, Epoch 200, NLL=12.6678, omega=0.1098, tau=0.0912, condition=regret_late
# Participant 811, Epoch 300, NLL=12.4717, omega=0.0856, tau=0.0917, condition=regret_late
# Participant 811, Epoch 400, NLL=12.3648, omega=0.0699, tau=0.0945, condition=regret_late
# Participant 811, Epoch 500, NLL=12.2975, omega=0.0587, tau=0.0965, condition=regret_late
# Participant 823, Epoch 1, NLL=34.0739, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 823, Epoch 100, NLL=30.8970, omega=0.2162, tau=0.4538, condition=regret_late
# Participant 823, Epoch 200, NLL=15.1637, omega=0.0646, tau=0.0747, condition=regret_late
# Participant 823, Epoch 300, NLL=14.1917, omega=0.0554, tau=0.0560, condition=regret_late
# Participant 823, Epoch 400, NLL=14.1916, omega=0.0556, tau=0.0559, condition=regret_late
# Participant 823, Epoch 500, NLL=14.1916, omega=0.0558, tau=0.0558, condition=regret_late
# Participant 764, Epoch 1, NLL=32.7390, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 764, Epoch 100, NLL=31.9756, omega=0.2320, tau=0.6353, condition=regret_late
# Participant 764, Epoch 200, NLL=31.6286, omega=0.1180, tau=0.5649, condition=regret_late
# Participant 764, Epoch 300, NLL=31.4806, omega=0.0712, tau=0.5576, condition=regret_late
# Participant 764, Epoch 400, NLL=31.4095, omega=0.0484, tau=0.5570, condition=regret_late
# Participant 764, Epoch 500, NLL=31.3697, omega=0.0355, tau=0.5574, condition=regret_late
# Participant 863, Epoch 1, NLL=31.1800, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 863, Epoch 100, NLL=19.5757, omega=0.1910, tau=0.1623, condition=regret_late
# Participant 863, Epoch 200, NLL=2.3647, omega=0.0826, tau=0.0466, condition=regret_late
# Participant 863, Epoch 300, NLL=1.3332, omega=0.0696, tau=0.0329, condition=regret_late
# Participant 863, Epoch 400, NLL=1.1967, omega=0.0653, tau=0.0285, condition=regret_late
# Participant 863, Epoch 500, NLL=1.1527, omega=0.0629, tau=0.0261, condition=regret_late
# Participant 780, Epoch 1, NLL=28.9700, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 780, Epoch 100, NLL=25.0780, omega=0.2189, tau=0.2152, condition=regret_late
# Participant 780, Epoch 200, NLL=24.7242, omega=0.1394, tau=0.1973, condition=regret_late
# Participant 780, Epoch 300, NLL=24.6403, omega=0.1030, tau=0.2036, condition=regret_late
# Participant 780, Epoch 400, NLL=24.6002, omega=0.0815, tau=0.2076, condition=regret_late
# Participant 780, Epoch 500, NLL=24.5783, omega=0.0676, tau=0.2103, condition=regret_late
# Participant 770, Epoch 1, NLL=31.6156, omega=0.5039, tau=0.5039, condition=regret_late
# Participant 770, Epoch 100, NLL=31.4591, omega=1.0107, tau=0.4426, condition=regret_late
# Participant 770, Epoch 200, NLL=31.3300, omega=1.6979, tau=0.3682, condition=regret_late
# Participant 770, Epoch 300, NLL=31.2434, omega=2.3914, tau=0.3209, condition=regret_late
# Participant 770, Epoch 400, NLL=31.1861, omega=3.0266, tau=0.2897, condition=regret_late
# Participant 770, Epoch 500, NLL=31.1464, omega=3.5992, tau=0.2676, condition=regret_late
# Participant 795, Epoch 1, NLL=31.8065, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 795, Epoch 100, NLL=22.4603, omega=0.1838, tau=0.1563, condition=regret_late
# Participant 795, Epoch 200, NLL=8.8712, omega=0.0670, tau=0.0485, condition=regret_late
# Participant 795, Epoch 300, NLL=8.1274, omega=0.0460, tau=0.0450, condition=regret_late
# Participant 795, Epoch 400, NLL=7.8718, omega=0.0358, tau=0.0463, condition=regret_late
# Participant 795, Epoch 500, NLL=7.7270, omega=0.0292, tau=0.0470, condition=regret_late
# Participant 813, Epoch 1, NLL=33.4531, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 813, Epoch 100, NLL=31.4771, omega=0.2161, tau=0.4333, condition=regret_late
# Participant 813, Epoch 200, NLL=18.4434, omega=0.0543, tau=0.0665, condition=regret_late
# Participant 813, Epoch 300, NLL=15.8702, omega=0.0259, tau=0.0471, condition=regret_late
# Participant 813, Epoch 400, NLL=15.5539, omega=0.0179, tau=0.0478, condition=regret_late
# Participant 813, Epoch 500, NLL=15.4038, omega=0.0136, tau=0.0483, condition=regret_late
# Participant 758, Epoch 1, NLL=24.8638, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 758, Epoch 100, NLL=17.5150, omega=0.2315, tau=0.2055, condition=regret_late
# Participant 758, Epoch 200, NLL=15.6043, omega=0.2018, tau=0.1270, condition=regret_late
# Participant 758, Epoch 300, NLL=15.5421, omega=0.2682, tau=0.1218, condition=regret_late
# Participant 758, Epoch 400, NLL=15.4704, omega=0.3741, tau=0.1171, condition=regret_late
# Participant 758, Epoch 500, NLL=15.4157, omega=0.4993, tau=0.1118, condition=regret_late
# Participant 786, Epoch 1, NLL=30.4695, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 786, Epoch 100, NLL=24.4363, omega=0.2015, tau=0.1842, condition=regret_late
# Participant 786, Epoch 200, NLL=21.7796, omega=0.1062, tau=0.1059, condition=regret_late
# Participant 786, Epoch 300, NLL=21.6278, omega=0.0799, tau=0.1115, condition=regret_late
# Participant 786, Epoch 400, NLL=21.5613, omega=0.0647, tau=0.1148, condition=regret_late
# Participant 786, Epoch 500, NLL=21.5255, omega=0.0547, tau=0.1171, condition=regret_late
# Participant 831, Epoch 1, NLL=33.9471, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 831, Epoch 100, NLL=31.8316, omega=0.2244, tau=0.6215, condition=regret_late
# Participant 831, Epoch 200, NLL=25.1238, omega=0.0700, tau=0.1540, condition=regret_late
# Participant 831, Epoch 300, NLL=19.8806, omega=0.0210, tau=0.0771, condition=regret_late
# Participant 831, Epoch 400, NLL=18.8659, omega=0.0113, tau=0.0706, condition=regret_late
# Participant 831, Epoch 500, NLL=18.4877, omega=0.0076, tau=0.0687, condition=regret_late
# Participant 800, Epoch 1, NLL=35.9247, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 800, Epoch 100, NLL=33.8958, omega=0.2374, tau=0.8735, condition=regret_late
# Participant 800, Epoch 200, NLL=33.4100, omega=0.1325, tau=1.1268, condition=regret_late
# Participant 800, Epoch 300, NLL=33.2233, omega=0.0846, tau=1.3101, condition=regret_late
# Participant 800, Epoch 400, NLL=33.1327, omega=0.0595, tau=1.4544, condition=regret_late
# Participant 800, Epoch 500, NLL=33.0817, omega=0.0447, tau=1.5751, condition=regret_late
# Participant 762, Epoch 1, NLL=27.9355, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 762, Epoch 100, NLL=20.0129, omega=0.1912, tau=0.1885, condition=regret_late
# Participant 762, Epoch 200, NLL=13.3925, omega=0.0970, tau=0.0772, condition=regret_late
# Participant 762, Epoch 300, NLL=13.2360, omega=0.1160, tau=0.0676, condition=regret_late
# Participant 762, Epoch 400, NLL=13.2144, omega=0.1302, tau=0.0649, condition=regret_late
# Participant 762, Epoch 500, NLL=13.2132, omega=0.1336, tau=0.0642, condition=regret_late
# Participant 815, Epoch 1, NLL=40.0621, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 815, Epoch 100, NLL=35.0066, omega=0.2334, tau=0.8684, condition=regret_late
# Participant 815, Epoch 200, NLL=33.4450, omega=0.1208, tau=1.0583, condition=regret_late
# Participant 815, Epoch 300, NLL=32.6868, omega=0.0687, tau=1.0862, condition=regret_late
# Participant 815, Epoch 400, NLL=32.1359, omega=0.0418, tau=0.9709, condition=regret_late
# Participant 815, Epoch 500, NLL=31.3577, omega=0.0259, tau=0.6990, condition=regret_late
# Participant 875, Epoch 1, NLL=32.5098, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 875, Epoch 100, NLL=25.4206, omega=0.1923, tau=0.1526, condition=regret_late
# Participant 875, Epoch 200, NLL=17.6821, omega=0.0725, tau=0.0605, condition=regret_late
# Participant 875, Epoch 300, NLL=16.5626, omega=0.0422, tau=0.0615, condition=regret_late
# Participant 875, Epoch 400, NLL=16.1024, omega=0.0289, tau=0.0621, condition=regret_late
# Participant 875, Epoch 500, NLL=15.8514, omega=0.0214, tau=0.0625, condition=regret_late
# Participant 869, Epoch 1, NLL=29.4374, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 869, Epoch 100, NLL=26.3715, omega=1.0340, tau=0.2000, condition=regret_late
# Participant 869, Epoch 200, NLL=24.0234, omega=2.0409, tau=0.0880, condition=regret_late
# Participant 869, Epoch 300, NLL=23.8874, omega=2.4810, tau=0.0731, condition=regret_late
# Participant 869, Epoch 400, NLL=23.8867, omega=2.5399, tau=0.0723, condition=regret_late
# Participant 869, Epoch 500, NLL=23.8867, omega=2.5428, tau=0.0722, condition=regret_late
# Participant 778, Epoch 1, NLL=30.7377, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 778, Epoch 100, NLL=30.6267, omega=0.3121, tau=0.4135, condition=regret_late
# Participant 778, Epoch 200, NLL=30.6199, omega=0.2073, tau=0.4292, condition=regret_late
# Participant 778, Epoch 300, NLL=30.6163, omega=0.1456, tau=0.4396, condition=regret_late
# Participant 778, Epoch 400, NLL=30.6144, omega=0.1097, tau=0.4462, condition=regret_late
# Participant 778, Epoch 500, NLL=30.6134, omega=0.0871, tau=0.4506, condition=regret_late
# Participant 842, Epoch 1, NLL=28.9702, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 842, Epoch 100, NLL=21.8094, omega=0.1941, tau=0.1862, condition=regret_late
# Participant 842, Epoch 200, NLL=17.1757, omega=0.1107, tau=0.0841, condition=regret_late
# Participant 842, Epoch 300, NLL=17.1480, omega=0.1222, tau=0.0800, condition=regret_late
# Participant 842, Epoch 400, NLL=17.1388, omega=0.1311, tau=0.0779, condition=regret_late
# Participant 842, Epoch 500, NLL=17.1370, omega=0.1355, tau=0.0769, condition=regret_late
# Participant 766, Epoch 1, NLL=28.2950, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 766, Epoch 100, NLL=15.9025, omega=0.2003, tau=0.1787, condition=regret_late
# Participant 766, Epoch 200, NLL=2.8520, omega=0.0984, tau=0.0621, condition=regret_late
# Participant 766, Epoch 300, NLL=1.6155, omega=0.0817, tau=0.0428, condition=regret_late
# Participant 766, Epoch 400, NLL=1.3722, omega=0.0751, tau=0.0355, condition=regret_late
# Participant 766, Epoch 500, NLL=1.2732, omega=0.0710, tau=0.0313, condition=regret_late
# Participant 844, Epoch 1, NLL=35.5367, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 844, Epoch 100, NLL=33.6367, omega=0.2008, tau=0.8671, condition=regret_late
# Participant 844, Epoch 200, NLL=32.9957, omega=0.0821, tau=1.0461, condition=regret_late
# Participant 844, Epoch 300, NLL=32.7419, omega=0.0417, tau=1.0791, condition=regret_late
# Participant 844, Epoch 400, NLL=32.6077, omega=0.0247, tau=1.0233, condition=regret_late
# Participant 844, Epoch 500, NLL=32.5021, omega=0.0160, tau=0.9069, condition=regret_late
# Participant 776, Epoch 1, NLL=33.6567, omega=0.5039, tau=0.5039, condition=regret_late
# Participant 776, Epoch 100, NLL=32.9549, omega=0.9442, tau=0.8356, condition=regret_late
# Participant 776, Epoch 200, NLL=32.8149, omega=1.4061, tau=0.9787, condition=regret_late
# Participant 776, Epoch 300, NLL=32.7515, omega=1.8552, tau=1.0027, condition=regret_late
# Participant 776, Epoch 400, NLL=32.7045, omega=2.2952, tau=0.9468, condition=regret_late
# Participant 776, Epoch 500, NLL=32.6572, omega=2.7454, tau=0.8371, condition=regret_late
# Participant 867, Epoch 1, NLL=30.6050, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 867, Epoch 100, NLL=21.7331, omega=0.1981, tau=0.1729, condition=regret_late
# Participant 867, Epoch 200, NLL=13.2918, omega=0.0999, tau=0.0619, condition=regret_late
# Participant 867, Epoch 300, NLL=13.2119, omega=0.0993, tau=0.0561, condition=regret_late
# Participant 867, Epoch 400, NLL=13.2071, omega=0.1035, tau=0.0553, condition=regret_late
# Participant 867, Epoch 500, NLL=13.2044, omega=0.1070, tau=0.0546, condition=regret_late
# Participant 821, Epoch 1, NLL=28.8942, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 821, Epoch 100, NLL=22.0950, omega=0.1986, tau=0.1868, condition=regret_late
# Participant 821, Epoch 200, NLL=15.5906, omega=0.0919, tau=0.0727, condition=regret_late
# Participant 821, Epoch 300, NLL=15.5103, omega=0.0809, tau=0.0672, condition=regret_late
# Participant 821, Epoch 400, NLL=15.5097, omega=0.0789, tau=0.0674, condition=regret_late
# Participant 821, Epoch 500, NLL=15.5097, omega=0.0785, tau=0.0674, condition=regret_late
# Participant 871, Epoch 1, NLL=31.3563, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 871, Epoch 100, NLL=30.2379, omega=0.2131, tau=0.2572, condition=regret_late
# Participant 871, Epoch 200, NLL=29.9728, omega=0.1102, tau=0.2653, condition=regret_late
# Participant 871, Epoch 300, NLL=29.8714, omega=0.0693, tau=0.2702, condition=regret_late
# Participant 871, Epoch 400, NLL=29.8221, omega=0.0485, tau=0.2731, condition=regret_late
# Participant 871, Epoch 500, NLL=29.7939, omega=0.0363, tau=0.2750, condition=regret_late
# Participant 838, Epoch 1, NLL=29.4247, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 838, Epoch 100, NLL=20.6497, omega=0.1955, tau=0.1795, condition=regret_late
# Participant 838, Epoch 200, NLL=10.6411, omega=0.0811, tau=0.0627, condition=regret_late
# Participant 838, Epoch 300, NLL=9.8875, omega=0.0519, tau=0.0513, condition=regret_late
# Participant 838, Epoch 400, NLL=9.6909, omega=0.0379, tau=0.0505, condition=regret_late
# Participant 838, Epoch 500, NLL=9.5847, omega=0.0296, tau=0.0502, condition=regret_late
# Participant 854, Epoch 1, NLL=30.2727, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 854, Epoch 100, NLL=27.4105, omega=0.2660, tau=0.1980, condition=regret_late
# Participant 854, Epoch 200, NLL=25.1294, omega=0.7245, tau=0.0884, condition=regret_late
# Participant 854, Epoch 300, NLL=24.8503, omega=1.1461, tau=0.0700, condition=regret_late
# Participant 854, Epoch 400, NLL=24.8436, omega=1.2390, tau=0.0677, condition=regret_late
# Participant 854, Epoch 500, NLL=24.8435, omega=1.2530, tau=0.0674, condition=regret_late
# Participant 802, Epoch 1, NLL=32.1838, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 802, Epoch 100, NLL=31.1931, omega=0.2115, tau=0.4208, condition=regret_late
# Participant 802, Epoch 200, NLL=30.3096, omega=0.0845, tau=0.3393, condition=regret_late
# Participant 802, Epoch 300, NLL=29.9812, omega=0.0456, tau=0.3279, condition=regret_late
# Participant 802, Epoch 400, NLL=29.8457, omega=0.0296, tau=0.3256, condition=regret_late
# Participant 802, Epoch 500, NLL=29.7756, omega=0.0212, tau=0.3249, condition=regret_late
# Participant 827, Epoch 1, NLL=35.8724, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 827, Epoch 100, NLL=32.6265, omega=0.2309, tau=0.7570, condition=regret_late
# Participant 827, Epoch 200, NLL=29.1033, omega=0.1004, tau=0.3835, condition=regret_late
# Participant 827, Epoch 300, NLL=19.5743, omega=0.0354, tau=0.0849, condition=regret_late
# Participant 827, Epoch 400, NLL=18.9566, omega=0.0218, tau=0.0903, condition=regret_late
# Participant 827, Epoch 500, NLL=18.7146, omega=0.0157, tau=0.0923, condition=regret_late
# Participant 849, Epoch 1, NLL=31.7627, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 849, Epoch 100, NLL=27.9264, omega=0.1894, tau=0.1790, condition=regret_late
# Participant 849, Epoch 200, NLL=25.5090, omega=0.0751, tau=0.1226, condition=regret_late
# Participant 849, Epoch 300, NLL=24.9944, omega=0.0440, tau=0.1236, condition=regret_late
# Participant 849, Epoch 400, NLL=24.7725, omega=0.0300, tau=0.1245, condition=regret_late
# Participant 849, Epoch 500, NLL=24.6508, omega=0.0221, tau=0.1250, condition=regret_late
# Participant 856, Epoch 1, NLL=34.4675, omega=0.5039, tau=0.5039, condition=regret_late
# Participant 856, Epoch 100, NLL=33.2815, omega=0.8976, tau=0.8512, condition=regret_late
# Participant 856, Epoch 200, NLL=33.0892, omega=1.2050, tau=1.0708, condition=regret_late
# Participant 856, Epoch 300, NLL=33.0251, omega=1.4338, tau=1.2310, condition=regret_late
# Participant 856, Epoch 400, NLL=32.9959, omega=1.6059, tau=1.3599, condition=regret_late
# Participant 856, Epoch 500, NLL=32.9800, omega=1.7370, tau=1.4694, condition=regret_late
# Participant 797, Epoch 1, NLL=27.5731, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 797, Epoch 100, NLL=22.3974, omega=0.2531, tau=0.2026, condition=regret_late
# Participant 797, Epoch 200, NLL=18.7741, omega=0.6602, tau=0.0973, condition=regret_late
# Participant 797, Epoch 300, NLL=12.9736, omega=1.6157, tau=0.0367, condition=regret_late
# Participant 797, Epoch 400, NLL=7.7204, omega=2.6014, tau=0.0136, condition=regret_late
# Participant 797, Epoch 500, NLL=nan, omega=nan, tau=nan, condition=regret_late
# Participant 804, Epoch 1, NLL=30.8317, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 804, Epoch 100, NLL=29.2230, omega=0.2357, tau=0.2408, condition=regret_late
# Participant 804, Epoch 200, NLL=29.1284, omega=0.1658, tau=0.2541, condition=regret_late
# Participant 804, Epoch 300, NLL=29.0857, omega=0.1258, tau=0.2670, condition=regret_late
# Participant 804, Epoch 400, NLL=29.0631, omega=0.1004, tau=0.2758, condition=regret_late
# Participant 804, Epoch 500, NLL=29.0497, omega=0.0831, tau=0.2822, condition=regret_late
# Participant 752, Epoch 1, NLL=30.5245, omega=0.5039, tau=0.4961, condition=regret_late
# Participant 752, Epoch 100, NLL=29.2095, omega=1.1487, tau=0.2184, condition=regret_late
# Participant 752, Epoch 200, NLL=28.5898, omega=2.0407, tau=0.1337, condition=regret_late
# Participant 752, Epoch 300, NLL=28.5168, omega=2.4771, tau=0.1175, condition=regret_late
# Participant 752, Epoch 400, NLL=28.5114, omega=2.6153, tau=0.1137, condition=regret_late
# Participant 752, Epoch 500, NLL=28.5111, omega=2.6494, tau=0.1129, condition=regret_late
# Participant 861, Epoch 1, NLL=32.2212, omega=0.5039, tau=0.5039, condition=regret_late
# Participant 861, Epoch 100, NLL=31.9124, omega=1.0144, tau=0.3672, condition=regret_late
# Participant 861, Epoch 200, NLL=31.6783, omega=1.6635, tau=0.2836, condition=regret_late
# Participant 861, Epoch 300, NLL=31.5375, omega=2.2879, tau=0.2364, condition=regret_late
# Participant 861, Epoch 400, NLL=31.4517, omega=2.8417, tau=0.2072, condition=regret_late
# Participant 861, Epoch 500, NLL=31.3955, omega=3.3308, tau=0.1873, condition=regret_late
# Participant 817, Epoch 1, NLL=31.4248, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 817, Epoch 100, NLL=27.3217, omega=0.1921, tau=0.1784, condition=regret_late
# Participant 817, Epoch 200, NLL=24.7064, omega=0.0995, tau=0.0874, condition=regret_late
# Participant 817, Epoch 300, NLL=24.6751, omega=0.0855, tau=0.0911, condition=regret_late
# Participant 817, Epoch 400, NLL=24.6666, omega=0.0781, tau=0.0927, condition=regret_late
# Participant 817, Epoch 500, NLL=24.6640, omega=0.0740, tau=0.0937, condition=regret_late
# Participant 858, Epoch 1, NLL=34.2078, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 858, Epoch 100, NLL=32.9216, omega=0.2330, tau=0.7898, condition=regret_late
# Participant 858, Epoch 200, NLL=32.3221, omega=0.1152, tau=0.6499, condition=regret_late
# Participant 858, Epoch 300, NLL=30.4139, omega=0.0484, tau=0.1987, condition=regret_late
# Participant 858, Epoch 400, NLL=29.2370, omega=0.0189, tau=0.1185, condition=regret_late
# Participant 858, Epoch 500, NLL=29.0522, omega=0.0116, tau=0.1168, condition=regret_late
# Participant 840, Epoch 1, NLL=33.8831, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 840, Epoch 100, NLL=32.3729, omega=0.2263, tau=0.6476, condition=regret_late
# Participant 840, Epoch 200, NLL=27.6579, omega=0.0762, tau=0.1559, condition=regret_late
# Participant 840, Epoch 300, NLL=25.2551, omega=0.0314, tau=0.0955, condition=regret_late
# Participant 840, Epoch 400, NLL=24.9957, omega=0.0206, tau=0.0977, condition=regret_late
# Participant 840, Epoch 500, NLL=24.8820, omega=0.0153, tau=0.0991, condition=regret_late
# Participant 774, Epoch 1, NLL=28.3372, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 774, Epoch 100, NLL=21.4317, omega=0.2110, tau=0.1943, condition=regret_late
# Participant 774, Epoch 200, NLL=19.7539, omega=0.1691, tau=0.1253, condition=regret_late
# Participant 774, Epoch 300, NLL=19.7154, omega=0.1979, tau=0.1203, condition=regret_late
# Participant 774, Epoch 400, NLL=19.6754, omega=0.2337, tau=0.1138, condition=regret_late
# Participant 774, Epoch 500, NLL=19.6434, omega=0.2723, tau=0.1072, condition=regret_late
# Participant 819, Epoch 1, NLL=29.4861, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 819, Epoch 100, NLL=24.9840, omega=0.1947, tau=0.2127, condition=regret_late
# Participant 819, Epoch 200, NLL=23.1337, omega=0.0837, tau=0.1889, condition=regret_late
# Participant 819, Epoch 300, NLL=22.5563, omega=0.0487, tau=0.1918, condition=regret_late
# Participant 819, Epoch 400, NLL=22.2948, omega=0.0328, tau=0.1937, condition=regret_late
# Participant 819, Epoch 500, NLL=22.1506, omega=0.0239, tau=0.1949, condition=regret_late
# Participant 807, Epoch 1, NLL=32.9773, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 807, Epoch 100, NLL=31.3634, omega=0.2098, tau=0.3521, condition=regret_late
# Participant 807, Epoch 200, NLL=27.2482, omega=0.0566, tau=0.1137, condition=regret_late
# Participant 807, Epoch 300, NLL=25.6570, omega=0.0233, tau=0.0925, condition=regret_late
# Participant 807, Epoch 400, NLL=25.1552, omega=0.0136, tau=0.0877, condition=regret_late
# Participant 807, Epoch 500, NLL=24.9251, omega=0.0093, tau=0.0858, condition=regret_late
# Participant 829, Epoch 1, NLL=38.3541, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 829, Epoch 100, NLL=34.5860, omega=0.2280, tau=0.8723, condition=regret_late
# Participant 829, Epoch 200, NLL=33.4014, omega=0.1127, tau=1.0800, condition=regret_late
# Participant 829, Epoch 300, NLL=32.8608, omega=0.0622, tau=1.1460, condition=regret_late
# Participant 829, Epoch 400, NLL=32.5430, omega=0.0377, tau=1.1035, condition=regret_late
# Participant 829, Epoch 500, NLL=32.2734, omega=0.0244, tau=0.9665, condition=regret_late
# Participant 792, Epoch 1, NLL=33.0049, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 792, Epoch 100, NLL=23.4445, omega=0.1866, tau=0.1662, condition=regret_late
# Participant 792, Epoch 200, NLL=2.8054, omega=0.0715, tau=0.0387, condition=regret_late
# Participant 792, Epoch 300, NLL=1.5761, omega=0.0585, tau=0.0261, condition=regret_late
# Participant 792, Epoch 400, NLL=1.3644, omega=0.0533, tau=0.0218, condition=regret_late
# Participant 792, Epoch 500, NLL=1.2715, omega=0.0497, tau=0.0191, condition=regret_late
# Participant 782, Epoch 1, NLL=33.0387, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 782, Epoch 100, NLL=26.8306, omega=0.1897, tau=0.1999, condition=regret_late
# Participant 782, Epoch 200, NLL=7.5344, omega=0.0563, tau=0.0402, condition=regret_late
# Participant 782, Epoch 300, NLL=6.3334, omega=0.0402, tau=0.0299, condition=regret_late
# Participant 782, Epoch 400, NLL=6.2613, omega=0.0352, tau=0.0308, condition=regret_late
# Participant 782, Epoch 500, NLL=6.2210, omega=0.0316, tau=0.0318, condition=regret_late
# Participant 873, Epoch 1, NLL=32.2949, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 873, Epoch 100, NLL=29.7017, omega=0.1809, tau=0.1827, condition=regret_late
# Participant 873, Epoch 200, NLL=27.6099, omega=0.0702, tau=0.1464, condition=regret_late
# Participant 873, Epoch 300, NLL=27.1918, omega=0.0436, tau=0.1485, condition=regret_late
# Participant 873, Epoch 400, NLL=27.0405, omega=0.0318, tau=0.1508, condition=regret_late
# Participant 873, Epoch 500, NLL=26.9637, omega=0.0250, tau=0.1526, condition=regret_late
# Participant 852, Epoch 1, NLL=28.1601, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 852, Epoch 100, NLL=16.5848, omega=0.1963, tau=0.1814, condition=regret_late
# Participant 852, Epoch 200, NLL=5.5681, omega=0.0904, tau=0.0672, condition=regret_late
# Participant 852, Epoch 300, NLL=5.0954, omega=0.0750, tau=0.0546, condition=regret_late
# Participant 852, Epoch 400, NLL=5.0787, omega=0.0694, tau=0.0543, condition=regret_late
# Participant 852, Epoch 500, NLL=5.0666, omega=0.0647, tau=0.0551, condition=regret_late
# Participant 865, Epoch 1, NLL=30.8401, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 865, Epoch 100, NLL=29.6502, omega=0.2124, tau=0.3160, condition=regret_late
# Participant 865, Epoch 200, NLL=29.1691, omega=0.1047, tau=0.3164, condition=regret_late
# Participant 865, Epoch 300, NLL=28.9702, omega=0.0626, tau=0.3193, condition=regret_late
# Participant 865, Epoch 400, NLL=28.8725, omega=0.0422, tau=0.3214, condition=regret_late
# Participant 865, Epoch 500, NLL=28.8172, omega=0.0306, tau=0.3228, condition=regret_late
# Participant 772, Epoch 1, NLL=27.9733, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 772, Epoch 100, NLL=14.3803, omega=0.1997, tau=0.1793, condition=regret_late
# Participant 772, Epoch 200, NLL=3.2117, omega=0.1054, tau=0.0685, condition=regret_late
# Participant 772, Epoch 300, NLL=2.2008, omega=0.0902, tau=0.0485, condition=regret_late
# Participant 772, Epoch 400, NLL=1.9876, omega=0.0844, tau=0.0405, condition=regret_late
# Participant 772, Epoch 500, NLL=1.9059, omega=0.0809, tau=0.0359, condition=regret_late
# Participant 768, Epoch 1, NLL=32.3224, omega=0.5039, tau=0.5039, condition=regret_late
# Participant 768, Epoch 100, NLL=32.0839, omega=0.9335, tau=0.4992, condition=regret_late
# Participant 768, Epoch 200, NLL=31.9978, omega=1.3680, tau=0.4299, condition=regret_late
# Participant 768, Epoch 300, NLL=31.9813, omega=1.6110, tau=0.4086, condition=regret_late
# Participant 768, Epoch 400, NLL=31.9792, omega=1.7102, tau=0.4020, condition=regret_late
# Participant 768, Epoch 500, NLL=31.9790, omega=1.7428, tau=0.4001, condition=regret_late
# Participant 846, Epoch 1, NLL=31.9585, omega=0.4961, tau=0.5039, condition=regret_late
# Participant 846, Epoch 100, NLL=31.8816, omega=0.2389, tau=0.6034, condition=regret_late
# Participant 846, Epoch 200, NLL=31.8698, omega=0.1492, tau=0.6144, condition=regret_late
# Participant 846, Epoch 300, NLL=31.8661, omega=0.1097, tau=0.6206, condition=regret_late
# Participant 846, Epoch 400, NLL=31.8646, omega=0.0881, tau=0.6244, condition=regret_late
# Participant 846, Epoch 500, NLL=31.8638, omega=0.0745, tau=0.6270, condition=regret_late
# Participant 880, Epoch 1, NLL=48.8920, omega=0.0000, tau=0.4961, condition=control
# Participant 880, Epoch 100, NLL=32.8566, omega=0.0000, tau=0.1993, condition=control
# Participant 880, Epoch 200, NLL=23.3200, omega=0.0000, tau=0.0952, condition=control
# Participant 880, Epoch 300, NLL=23.0443, omega=0.0000, tau=0.0837, condition=control
# Participant 880, Epoch 400, NLL=23.0440, omega=0.0000, tau=0.0834, condition=control
# Participant 880, Epoch 500, NLL=23.0440, omega=0.0000, tau=0.0834, condition=control
# Participant 898, Epoch 1, NLL=64.1176, omega=0.0000, tau=0.5039, condition=control
# Participant 898, Epoch 100, NLL=63.9249, omega=0.0000, tau=0.6632, condition=control
# Participant 898, Epoch 200, NLL=63.9249, omega=0.0000, tau=0.6617, condition=control
# Participant 898, Epoch 300, NLL=63.9248, omega=0.0000, tau=0.6617, condition=control
# Participant 898, Epoch 400, NLL=63.9248, omega=0.0000, tau=0.6617, condition=control
# Participant 898, Epoch 500, NLL=63.9248, omega=0.0000, tau=0.6617, condition=control
# Participant 941, Epoch 1, NLL=54.2704, omega=0.0000, tau=0.4961, condition=control
# Participant 941, Epoch 100, NLL=45.1255, omega=0.0000, tau=0.2042, condition=control
# Participant 941, Epoch 200, NLL=41.0574, omega=0.0000, tau=0.1090, condition=control
# Participant 941, Epoch 300, NLL=41.0229, omega=0.0000, tau=0.1034, condition=control
# Participant 941, Epoch 400, NLL=41.0229, omega=0.0000, tau=0.1034, condition=control
# Participant 941, Epoch 500, NLL=41.0229, omega=0.0000, tau=0.1034, condition=control
# Participant 942, Epoch 1, NLL=55.4407, omega=0.0000, tau=0.4961, condition=control
# Participant 942, Epoch 100, NLL=44.8959, omega=0.0000, tau=0.1969, condition=control
# Participant 942, Epoch 200, NLL=38.2609, omega=0.0000, tau=0.0938, condition=control
# Participant 942, Epoch 300, NLL=38.2316, omega=0.0000, tau=0.0901, condition=control
# Participant 942, Epoch 400, NLL=38.2316, omega=0.0000, tau=0.0901, condition=control
# Participant 942, Epoch 500, NLL=38.2316, omega=0.0000, tau=0.0901, condition=control
# Participant 924, Epoch 1, NLL=56.4465, omega=0.0000, tau=0.4961, condition=control
# Participant 924, Epoch 100, NLL=54.8428, omega=0.0000, tau=0.2965, condition=control
# Participant 924, Epoch 200, NLL=54.8424, omega=0.0000, tau=0.2985, condition=control
# Participant 924, Epoch 300, NLL=54.8424, omega=0.0000, tau=0.2986, condition=control
# Participant 924, Epoch 400, NLL=54.8424, omega=0.0000, tau=0.2986, condition=control
# Participant 924, Epoch 500, NLL=54.8424, omega=0.0000, tau=0.2986, condition=control
# Participant 940, Epoch 1, NLL=52.5315, omega=0.0000, tau=0.4961, condition=control
# Participant 940, Epoch 100, NLL=48.6038, omega=0.0000, tau=0.2552, condition=control
# Participant 940, Epoch 200, NLL=48.5905, omega=0.0000, tau=0.2479, condition=control
# Participant 940, Epoch 300, NLL=48.5905, omega=0.0000, tau=0.2478, condition=control
# Participant 940, Epoch 400, NLL=48.5905, omega=0.0000, tau=0.2478, condition=control
# Participant 940, Epoch 500, NLL=48.5905, omega=0.0000, tau=0.2478, condition=control
# Participant 906, Epoch 1, NLL=57.7326, omega=0.0000, tau=0.4961, condition=control
# Participant 906, Epoch 100, NLL=55.4735, omega=0.0000, tau=0.2599, condition=control
# Participant 906, Epoch 200, NLL=55.4706, omega=0.0000, tau=0.2557, condition=control
# Participant 906, Epoch 300, NLL=55.4706, omega=0.0000, tau=0.2556, condition=control
# Participant 906, Epoch 400, NLL=55.4706, omega=0.0000, tau=0.2556, condition=control
# Participant 906, Epoch 500, NLL=55.4706, omega=0.0000, tau=0.2556, condition=control
# Participant 912, Epoch 1, NLL=43.5706, omega=0.0000, tau=0.4961, condition=control
# Participant 912, Epoch 100, NLL=30.7451, omega=0.0000, tau=0.2170, condition=control
# Participant 912, Epoch 200, NLL=28.6422, omega=0.0000, tau=0.1535, condition=control
# Participant 912, Epoch 300, NLL=28.6413, omega=0.0000, tau=0.1525, condition=control
# Participant 912, Epoch 400, NLL=28.6413, omega=0.0000, tau=0.1525, condition=control
# Participant 912, Epoch 500, NLL=28.6413, omega=0.0000, tau=0.1525, condition=control
# Participant 916, Epoch 1, NLL=49.9113, omega=0.0000, tau=0.4961, condition=control
# Participant 916, Epoch 100, NLL=34.0978, omega=0.0000, tau=0.1970, condition=control
# Participant 916, Epoch 200, NLL=19.5784, omega=0.0000, tau=0.0786, condition=control
# Participant 916, Epoch 300, NLL=17.7506, omega=0.0000, tau=0.0555, condition=control
# Participant 916, Epoch 400, NLL=17.7001, omega=0.0000, tau=0.0522, condition=control
# Participant 916, Epoch 500, NLL=17.6996, omega=0.0000, tau=0.0519, condition=control
# Participant 939, Epoch 1, NLL=62.9732, omega=0.0000, tau=0.4961, condition=control
# Participant 939, Epoch 100, NLL=62.9320, omega=0.0000, tau=0.4396, condition=control
# Participant 939, Epoch 200, NLL=62.9320, omega=0.0000, tau=0.4394, condition=control
# Participant 939, Epoch 300, NLL=62.9320, omega=0.0000, tau=0.4394, condition=control
# Participant 939, Epoch 400, NLL=62.9320, omega=0.0000, tau=0.4394, condition=control
# Participant 939, Epoch 500, NLL=62.9320, omega=0.0000, tau=0.4394, condition=control
# Participant 900, Epoch 1, NLL=63.9161, omega=0.0000, tau=0.4961, condition=control
# Participant 900, Epoch 100, NLL=63.8305, omega=0.0000, tau=0.3965, condition=control
# Participant 900, Epoch 200, NLL=63.8305, omega=0.0000, tau=0.3966, condition=control
# Participant 900, Epoch 300, NLL=63.8305, omega=0.0000, tau=0.3966, condition=control
# Participant 900, Epoch 400, NLL=63.8305, omega=0.0000, tau=0.3966, condition=control
# Participant 900, Epoch 500, NLL=63.8305, omega=0.0000, tau=0.3966, condition=control
# Participant 894, Epoch 1, NLL=63.5107, omega=0.0000, tau=0.4961, condition=control
# Participant 894, Epoch 100, NLL=63.2470, omega=0.0000, tau=0.3427, condition=control
# Participant 894, Epoch 200, NLL=63.2470, omega=0.0000, tau=0.3428, condition=control
# Participant 894, Epoch 300, NLL=63.2470, omega=0.0000, tau=0.3428, condition=control
# Participant 894, Epoch 400, NLL=63.2470, omega=0.0000, tau=0.3428, condition=control
# Participant 894, Epoch 500, NLL=63.2470, omega=0.0000, tau=0.3428, condition=control
# Participant 935, Epoch 1, NLL=60.4359, omega=0.0000, tau=0.5039, condition=control
# Participant 935, Epoch 100, NLL=60.2767, omega=0.0000, tau=0.5851, condition=control
# Participant 935, Epoch 200, NLL=60.2767, omega=0.0000, tau=0.5847, condition=control
# Participant 935, Epoch 300, NLL=60.2767, omega=0.0000, tau=0.5847, condition=control
# Participant 935, Epoch 400, NLL=60.2767, omega=0.0000, tau=0.5847, condition=control
# Participant 935, Epoch 500, NLL=60.2767, omega=0.0000, tau=0.5847, condition=control
# Participant 918, Epoch 1, NLL=43.8889, omega=0.0000, tau=0.4961, condition=control
# Participant 918, Epoch 100, NLL=22.5084, omega=0.0000, tau=0.1984, condition=control
# Participant 918, Epoch 200, NLL=7.2571, omega=0.0000, tau=0.0876, condition=control
# Participant 918, Epoch 300, NLL=5.4103, omega=0.0000, tau=0.0636, condition=control
# Participant 918, Epoch 400, NLL=5.1696, omega=0.0000, tau=0.0559, condition=control
# Participant 918, Epoch 500, NLL=5.1300, omega=0.0000, tau=0.0528, condition=control
# Participant 910, Epoch 1, NLL=55.0439, omega=0.0000, tau=0.4961, condition=control
# Participant 910, Epoch 100, NLL=48.4867, omega=0.0000, tau=0.2178, condition=control
# Participant 910, Epoch 200, NLL=47.9611, omega=0.0000, tau=0.1789, condition=control
# Participant 910, Epoch 300, NLL=47.9611, omega=0.0000, tau=0.1791, condition=control
# Participant 910, Epoch 400, NLL=47.9611, omega=0.0000, tau=0.1791, condition=control
# Participant 910, Epoch 500, NLL=47.9611, omega=0.0000, tau=0.1791, condition=control
# Participant 886, Epoch 1, NLL=61.9147, omega=0.0000, tau=0.4961, condition=control
# Participant 886, Epoch 100, NLL=61.8366, omega=0.0000, tau=0.4283, condition=control
# Participant 886, Epoch 200, NLL=61.8366, omega=0.0000, tau=0.4282, condition=control
# Participant 886, Epoch 300, NLL=61.8366, omega=0.0000, tau=0.4282, condition=control
# Participant 886, Epoch 400, NLL=61.8366, omega=0.0000, tau=0.4282, condition=control
# Participant 886, Epoch 500, NLL=61.8366, omega=0.0000, tau=0.4282, condition=control
# Participant 927, Epoch 1, NLL=50.1042, omega=0.0000, tau=0.4961, condition=control
# Participant 927, Epoch 100, NLL=39.5952, omega=0.0000, tau=0.2122, condition=control
# Participant 927, Epoch 200, NLL=37.7868, omega=0.0000, tau=0.1509, condition=control
# Participant 927, Epoch 300, NLL=37.7868, omega=0.0000, tau=0.1509, condition=control
# Participant 927, Epoch 400, NLL=37.7868, omega=0.0000, tau=0.1509, condition=control
# Participant 927, Epoch 500, NLL=37.7868, omega=0.0000, tau=0.1509, condition=control
# Participant 913, Epoch 1, NLL=50.1989, omega=0.0000, tau=0.4961, condition=control
# Participant 913, Epoch 100, NLL=43.2686, omega=0.0000, tau=0.2317, condition=control
# Participant 913, Epoch 200, NLL=43.0287, omega=0.0000, tau=0.2055, condition=control
# Participant 913, Epoch 300, NLL=43.0287, omega=0.0000, tau=0.2056, condition=control
# Participant 913, Epoch 400, NLL=43.0288, omega=0.0000, tau=0.2056, condition=control
# Participant 913, Epoch 500, NLL=43.0288, omega=0.0000, tau=0.2056, condition=control
# Participant 917, Epoch 1, NLL=46.1719, omega=0.0000, tau=0.4961, condition=control
# Participant 917, Epoch 100, NLL=26.0502, omega=0.0000, tau=0.1963, condition=control
# Participant 917, Epoch 200, NLL=7.0968, omega=0.0000, tau=0.0774, condition=control
# Participant 917, Epoch 300, NLL=3.6092, omega=0.0000, tau=0.0499, condition=control
# Participant 917, Epoch 400, NLL=2.9425, omega=0.0000, tau=0.0403, condition=control
# Participant 917, Epoch 500, NLL=2.7268, omega=0.0000, tau=0.0353, condition=control
# Participant 911, Epoch 1, NLL=52.3847, omega=0.0000, tau=0.4961, condition=control
# Participant 911, Epoch 100, NLL=34.8871, omega=0.0000, tau=0.1894, condition=control
# Participant 911, Epoch 200, NLL=7.1541, omega=0.0000, tau=0.0598, condition=control
# Participant 911, Epoch 300, NLL=2.0887, omega=0.0000, tau=0.0359, condition=control
# Participant 911, Epoch 400, NLL=1.4596, omega=0.0000, tau=0.0293, condition=control
# Participant 911, Epoch 500, NLL=1.2831, omega=0.0000, tau=0.0261, condition=control
# Participant 885, Epoch 1, NLL=42.5075, omega=0.0000, tau=0.4961, condition=control
# Participant 885, Epoch 100, NLL=20.1467, omega=0.0000, tau=0.1989, condition=control
# Participant 885, Epoch 200, NLL=4.6056, omega=0.0000, tau=0.0886, condition=control
# Participant 885, Epoch 300, NLL=2.5426, omega=0.0000, tau=0.0635, condition=control
# Participant 885, Epoch 400, NLL=2.1333, omega=0.0000, tau=0.0538, condition=control
# Participant 885, Epoch 500, NLL=1.9892, omega=0.0000, tau=0.0484, condition=control
# Participant 938, Epoch 1, NLL=51.3015, omega=0.0000, tau=0.4961, condition=control
# Participant 938, Epoch 100, NLL=40.7575, omega=0.0000, tau=0.2096, condition=control
# Participant 938, Epoch 200, NLL=38.6584, omega=0.0000, tau=0.1443, condition=control
# Participant 938, Epoch 300, NLL=38.6584, omega=0.0000, tau=0.1442, condition=control
# Participant 938, Epoch 400, NLL=38.6584, omega=0.0000, tau=0.1442, condition=control
# Participant 938, Epoch 500, NLL=38.6584, omega=0.0000, tau=0.1442, condition=control
# Participant 931, Epoch 1, NLL=61.1417, omega=0.0000, tau=0.4961, condition=control
# Participant 931, Epoch 100, NLL=60.8154, omega=0.0000, tau=0.3722, condition=control
# Participant 931, Epoch 200, NLL=60.8154, omega=0.0000, tau=0.3714, condition=control
# Participant 931, Epoch 300, NLL=60.8154, omega=0.0000, tau=0.3714, condition=control
# Participant 931, Epoch 400, NLL=60.8154, omega=0.0000, tau=0.3714, condition=control
# Participant 931, Epoch 500, NLL=60.8154, omega=0.0000, tau=0.3714, condition=control
# Participant 926, Epoch 1, NLL=49.1459, omega=0.0000, tau=0.4961, condition=control
# Participant 926, Epoch 100, NLL=30.7915, omega=0.0000, tau=0.1943, condition=control
# Participant 926, Epoch 200, NLL=11.0921, omega=0.0000, tau=0.0725, condition=control
# Participant 926, Epoch 300, NLL=7.7314, omega=0.0000, tau=0.0468, condition=control
# Participant 926, Epoch 400, NLL=7.4499, omega=0.0000, tau=0.0407, condition=control
# Participant 926, Epoch 500, NLL=7.4302, omega=0.0000, tau=0.0391, condition=control
# Participant 923, Epoch 1, NLL=46.2150, omega=0.0000, tau=0.4961, condition=control
# Participant 923, Epoch 100, NLL=32.8491, omega=0.0000, tau=0.2111, condition=control
# Participant 923, Epoch 200, NLL=29.5923, omega=0.0000, tau=0.1352, condition=control
# Participant 923, Epoch 300, NLL=29.5835, omega=0.0000, tau=0.1322, condition=control
# Participant 923, Epoch 400, NLL=29.5835, omega=0.0000, tau=0.1322, condition=control
# Participant 923, Epoch 500, NLL=29.5835, omega=0.0000, tau=0.1322, condition=control
# Participant 932, Epoch 1, NLL=51.3809, omega=0.0000, tau=0.4961, condition=control
# Participant 932, Epoch 100, NLL=38.6296, omega=0.0000, tau=0.2016, condition=control
# Participant 932, Epoch 200, NLL=32.9557, omega=0.0000, tau=0.1083, condition=control
# Participant 932, Epoch 300, NLL=32.9290, omega=0.0000, tau=0.1042, condition=control
# Participant 932, Epoch 400, NLL=32.9290, omega=0.0000, tau=0.1042, condition=control
# Participant 932, Epoch 500, NLL=32.9290, omega=0.0000, tau=0.1042, condition=control
# Participant 899, Epoch 1, NLL=52.3269, omega=0.0000, tau=0.4961, condition=control
# Participant 899, Epoch 100, NLL=39.7308, omega=0.0000, tau=0.1992, condition=control
# Participant 899, Epoch 200, NLL=31.9064, omega=0.0000, tau=0.0940, condition=control
# Participant 899, Epoch 300, NLL=31.7743, omega=0.0000, tau=0.0859, condition=control
# Participant 899, Epoch 400, NLL=31.7743, omega=0.0000, tau=0.0859, condition=control
# Participant 899, Epoch 500, NLL=31.7743, omega=0.0000, tau=0.0859, condition=control
# Participant 905, Epoch 1, NLL=51.2387, omega=0.0000, tau=0.4961, condition=control
# Participant 905, Epoch 100, NLL=41.8949, omega=0.0000, tau=0.2120, condition=control
# Participant 905, Epoch 200, NLL=39.7776, omega=0.0000, tau=0.1398, condition=control
# Participant 905, Epoch 300, NLL=39.7766, omega=0.0000, tau=0.1388, condition=control
# Participant 905, Epoch 400, NLL=39.7766, omega=0.0000, tau=0.1388, condition=control
# Participant 905, Epoch 500, NLL=39.7766, omega=0.0000, tau=0.1388, condition=control
# Participant 897, Epoch 1, NLL=62.7863, omega=0.0000, tau=0.5039, condition=control
# Participant 897, Epoch 100, NLL=62.5625, omega=0.0000, tau=0.6372, condition=control
# Participant 897, Epoch 200, NLL=62.5625, omega=0.0000, tau=0.6372, condition=control
# Participant 897, Epoch 300, NLL=62.5625, omega=0.0000, tau=0.6372, condition=control
# Participant 897, Epoch 400, NLL=62.5625, omega=0.0000, tau=0.6372, condition=control
# Participant 897, Epoch 500, NLL=62.5625, omega=0.0000, tau=0.6372, condition=control
# Participant 888, Epoch 1, NLL=46.6383, omega=0.0000, tau=0.4961, condition=control
# Participant 888, Epoch 100, NLL=25.4152, omega=0.0000, tau=0.1943, condition=control
# Participant 888, Epoch 200, NLL=5.0352, omega=0.0000, tau=0.0761, condition=control
# Participant 888, Epoch 300, NLL=2.0935, omega=0.0000, tau=0.0514, condition=control
# Participant 888, Epoch 400, NLL=1.5630, omega=0.0000, tau=0.0427, condition=control
# Participant 888, Epoch 500, NLL=1.3782, omega=0.0000, tau=0.0379, condition=control
# Participant 920, Epoch 1, NLL=62.4743, omega=0.0000, tau=0.4961, condition=control
# Participant 920, Epoch 100, NLL=61.9643, omega=0.0000, tau=0.3117, condition=control
# Participant 920, Epoch 200, NLL=61.9641, omega=0.0000, tau=0.3138, condition=control
# Participant 920, Epoch 300, NLL=61.9641, omega=0.0000, tau=0.3138, condition=control
# Participant 920, Epoch 400, NLL=61.9641, omega=0.0000, tau=0.3138, condition=control
# Participant 920, Epoch 500, NLL=61.9641, omega=0.0000, tau=0.3138, condition=control
# Participant 903, Epoch 1, NLL=55.9271, omega=0.0000, tau=0.4961, condition=control
# Participant 903, Epoch 100, NLL=52.7711, omega=0.0000, tau=0.2514, condition=control
# Participant 903, Epoch 200, NLL=52.7582, omega=0.0000, tau=0.2434, condition=control
# Participant 903, Epoch 300, NLL=52.7582, omega=0.0000, tau=0.2433, condition=control
# Participant 903, Epoch 400, NLL=52.7582, omega=0.0000, tau=0.2433, condition=control
# Participant 903, Epoch 500, NLL=52.7582, omega=0.0000, tau=0.2433, condition=control
# Participant 915, Epoch 1, NLL=40.6229, omega=0.0000, tau=0.4961, condition=control
# Participant 915, Epoch 100, NLL=18.8317, omega=0.0000, tau=0.2023, condition=control
# Participant 915, Epoch 200, NLL=7.0477, omega=0.0000, tau=0.0992, condition=control
# Participant 915, Epoch 300, NLL=6.0892, omega=0.0000, tau=0.0788, condition=control
# Participant 915, Epoch 400, NLL=6.0267, omega=0.0000, tau=0.0738, condition=control
# Participant 915, Epoch 500, NLL=6.0231, omega=0.0000, tau=0.0726, condition=control
# Participant 934, Epoch 1, NLL=58.6182, omega=0.0000, tau=0.4961, condition=control
# Participant 934, Epoch 100, NLL=57.3583, omega=0.0000, tau=0.2960, condition=control
# Participant 934, Epoch 200, NLL=57.3579, omega=0.0000, tau=0.2982, condition=control
# Participant 934, Epoch 300, NLL=57.3579, omega=0.0000, tau=0.2982, condition=control
# Participant 934, Epoch 400, NLL=57.3579, omega=0.0000, tau=0.2982, condition=control
# Participant 934, Epoch 500, NLL=57.3579, omega=0.0000, tau=0.2982, condition=control
# Participant 893, Epoch 1, NLL=63.8595, omega=0.0000, tau=0.4961, condition=control
# Participant 893, Epoch 100, NLL=63.7612, omega=0.0000, tau=0.3912, condition=control
# Participant 893, Epoch 200, NLL=63.7612, omega=0.0000, tau=0.3911, condition=control
# Participant 893, Epoch 300, NLL=63.7612, omega=0.0000, tau=0.3911, condition=control
# Participant 893, Epoch 400, NLL=63.7612, omega=0.0000, tau=0.3911, condition=control
# Participant 893, Epoch 500, NLL=63.7612, omega=0.0000, tau=0.3911, condition=control
# Participant 929, Epoch 1, NLL=48.5854, omega=0.0000, tau=0.4961, condition=control
# Participant 929, Epoch 100, NLL=36.6142, omega=0.0000, tau=0.2099, condition=control
# Participant 929, Epoch 200, NLL=33.6933, omega=0.0000, tau=0.1357, condition=control
# Participant 929, Epoch 300, NLL=33.6913, omega=0.0000, tau=0.1344, condition=control
# Participant 929, Epoch 400, NLL=33.6913, omega=0.0000, tau=0.1344, condition=control
# Participant 929, Epoch 500, NLL=33.6913, omega=0.0000, tau=0.1344, condition=control
# Participant 881, Epoch 1, NLL=55.8628, omega=0.0000, tau=0.4961, condition=control
# Participant 881, Epoch 100, NLL=41.9483, omega=0.0000, tau=0.1874, condition=control
# Participant 881, Epoch 200, NLL=13.2647, omega=0.0000, tau=0.0526, condition=control
# Participant 881, Epoch 300, NLL=5.6761, omega=0.0000, tau=0.0273, condition=control
# Participant 881, Epoch 400, NLL=4.4158, omega=0.0000, tau=0.0203, condition=control
# Participant 881, Epoch 500, NLL=3.9674, omega=0.0000, tau=0.0168, condition=control
# ...
# Participant 866, Epoch 200, NLL=30.5135, omega=0.4455, tau=0.2554, condition=regret_early
# Participant 866, Epoch 300, NLL=30.3287, omega=1.1588, tau=0.2059, condition=regret_early
# Participant 866, Epoch 400, NLL=29.7276, omega=2.9015, tau=0.1465, condition=regret_early
# Participant 866, Epoch 500, NLL=29.3168, omega=4.3545, tau=0.1251, condition=regret_early
# Participant 855, Epoch 1, NLL=31.8558, omega=0.5039, tau=0.4961, condition=regret_early
# Participant 855, Epoch 100, NLL=31.3210, omega=1.0066, tau=0.2278, condition=regret_early
# Participant 855, Epoch 200, NLL=31.2859, omega=1.2902, tau=0.1930, condition=regret_early
# Participant 855, Epoch 300, NLL=31.2859, omega=1.2890, tau=0.1931, condition=regret_early
# Participant 855, Epoch 400, NLL=31.2859, omega=1.2891, tau=0.1931, condition=regret_early
# Participant 855, Epoch 500, NLL=31.2859, omega=1.2891, tau=0.1931, condition=regret_early
# Participant 876, Epoch 1, NLL=28.8659, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 876, Epoch 100, NLL=26.5030, omega=0.7235, tau=0.2186, condition=regret_early
# Participant 876, Epoch 200, NLL=25.0115, omega=1.6640, tau=0.1120, condition=regret_early
# Participant 876, Epoch 300, NLL=24.5148, omega=2.5301, tau=0.0768, condition=regret_early
# Participant 876, Epoch 400, NLL=24.3267, omega=3.2103, tau=0.0618, condition=regret_early
# Participant 876, Epoch 500, NLL=24.2437, omega=3.7332, tau=0.0540, condition=regret_early
# Participant 754, Epoch 1, NLL=28.3128, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 754, Epoch 100, NLL=21.9901, omega=0.2111, tau=0.1962, condition=regret_early
# Participant 754, Epoch 200, NLL=20.1762, omega=0.1267, tau=0.1257, condition=regret_early
# Participant 754, Epoch 300, NLL=20.1086, omega=0.0989, tau=0.1283, condition=regret_early
# Participant 754, Epoch 400, NLL=20.0783, omega=0.0822, tau=0.1297, condition=regret_early
# Participant 754, Epoch 500, NLL=20.0631, omega=0.0713, tau=0.1307, condition=regret_early
# Participant 755, Epoch 1, NLL=36.2347, omega=0.4961, tau=0.5039, condition=regret_early
# Participant 755, Epoch 100, NLL=33.3382, omega=0.2311, tau=0.8260, condition=regret_early
# Participant 755, Epoch 200, NLL=32.2294, omega=0.1152, tau=0.8166, condition=regret_early
# Participant 755, Epoch 300, NLL=30.5228, omega=0.0566, tau=0.4416, condition=regret_early
# Participant 755, Epoch 400, NLL=25.5624, omega=0.0211, tau=0.1030, condition=regret_early
# Participant 755, Epoch 500, NLL=24.4428, omega=0.0094, tau=0.0851, condition=regret_early
# Participant 850, Epoch 1, NLL=31.0585, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 850, Epoch 100, NLL=27.9422, omega=0.1922, tau=0.1894, condition=regret_early
# Participant 850, Epoch 200, NLL=25.2762, omega=0.0759, tau=0.0828, condition=regret_early
# Participant 850, Epoch 300, NLL=25.1280, omega=0.0522, tau=0.0839, condition=regret_early
# Participant 850, Epoch 400, NLL=25.0876, omega=0.0420, tau=0.0857, condition=regret_early
# Participant 850, Epoch 500, NLL=25.0702, omega=0.0360, tau=0.0869, condition=regret_early
# Participant 828, Epoch 1, NLL=33.9263, omega=0.5039, tau=0.5039, condition=regret_early
# Participant 828, Epoch 100, NLL=33.1728, omega=1.0877, tau=0.8643, condition=regret_early
# Participant 828, Epoch 200, NLL=32.9578, omega=1.9247, tau=1.0757, condition=regret_early
# Participant 828, Epoch 300, NLL=32.8564, omega=2.7380, tau=1.1722, condition=regret_early
# Participant 828, Epoch 400, NLL=32.7942, omega=3.4741, tau=1.1881, condition=regret_early
# Participant 828, Epoch 500, NLL=32.7446, omega=4.1601, tau=1.1419, condition=regret_early
# Participant 820, Epoch 1, NLL=28.8406, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 820, Epoch 100, NLL=20.4130, omega=0.1971, tau=0.1859, condition=regret_early
# Participant 820, Epoch 200, NLL=14.1180, omega=0.0852, tau=0.0827, condition=regret_early
# Participant 820, Epoch 300, NLL=13.7201, omega=0.0575, tau=0.0803, condition=regret_early
# Participant 820, Epoch 400, NLL=13.5757, omega=0.0440, tau=0.0822, condition=regret_early
# Participant 820, Epoch 500, NLL=13.4988, omega=0.0357, tau=0.0834, condition=regret_early
# Participant 818, Epoch 1, NLL=31.8003, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 818, Epoch 100, NLL=30.5528, omega=0.1917, tau=0.2035, condition=regret_early
# Participant 818, Epoch 200, NLL=30.1570, omega=0.0906, tau=0.1506, condition=regret_early
# Participant 818, Epoch 300, NLL=30.1387, omega=0.0717, tau=0.1516, condition=regret_early
# Participant 818, Epoch 400, NLL=30.1365, omega=0.0655, tau=0.1523, condition=regret_early
# Participant 818, Epoch 500, NLL=30.1361, omega=0.0631, tau=0.1525, condition=regret_early
# Participant 787, Epoch 1, NLL=34.0362, omega=0.4961, tau=0.5039, condition=regret_early
# Participant 787, Epoch 100, NLL=30.6574, omega=0.2166, tau=0.4346, condition=regret_early
# Participant 787, Epoch 200, NLL=8.5499, omega=0.0567, tau=0.0649, condition=regret_early
# Participant 787, Epoch 300, NLL=1.5690, omega=0.0331, tau=0.0264, condition=regret_early
# Participant 787, Epoch 400, NLL=1.2608, omega=0.0294, tau=0.0210, condition=regret_early
# Participant 787, Epoch 500, NLL=1.1831, omega=0.0277, tau=0.0185, condition=regret_early
# Participant 843, Epoch 1, NLL=31.7736, omega=0.5039, tau=0.4961, condition=regret_early
# Participant 843, Epoch 100, NLL=31.0467, omega=1.0690, tau=0.2205, condition=regret_early
# Participant 843, Epoch 200, NLL=30.8573, omega=1.7732, tau=0.1686, condition=regret_early
# Participant 843, Epoch 300, NLL=30.8096, omega=2.2783, tau=0.1566, condition=regret_early
# Participant 843, Epoch 400, NLL=30.7819, omega=2.7186, tau=0.1486, condition=regret_early
# Participant 843, Epoch 500, NLL=30.7603, omega=3.1452, tau=0.1420, condition=regret_early
# Participant 848, Epoch 1, NLL=30.4449, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 848, Epoch 100, NLL=25.8724, omega=0.2094, tau=0.1897, condition=regret_early
# Participant 848, Epoch 200, NLL=24.6422, omega=0.1440, tau=0.1249, condition=regret_early
# Participant 848, Epoch 300, NLL=24.6330, omega=0.1316, tau=0.1277, condition=regret_early
# Participant 848, Epoch 400, NLL=24.6289, omega=0.1228, tau=0.1294, condition=regret_early
# Participant 848, Epoch 500, NLL=24.6272, omega=0.1171, tau=0.1305, condition=regret_early
# Participant 805, Epoch 1, NLL=31.7714, omega=0.5039, tau=0.4961, condition=regret_early
# Participant 805, Epoch 100, NLL=31.0818, omega=1.0729, tau=0.2476, condition=regret_early
# Participant 805, Epoch 200, NLL=30.6823, omega=1.8209, tau=0.1816, condition=regret_early
# Participant 805, Epoch 300, NLL=30.4750, omega=2.4880, tau=0.1499, condition=regret_early
# Participant 805, Epoch 400, NLL=30.3537, omega=3.0645, tau=0.1309, condition=regret_early
# Participant 805, Epoch 500, NLL=30.2735, omega=3.5737, tau=0.1178, condition=regret_early
# Participant 874, Epoch 1, NLL=31.9200, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 874, Epoch 100, NLL=30.4188, omega=0.1785, tau=0.1913, condition=regret_early
# Participant 874, Epoch 200, NLL=29.5962, omega=0.0849, tau=0.1143, condition=regret_early
# Participant 874, Epoch 300, NLL=29.5939, omega=0.0797, tau=0.1157, condition=regret_early
# Participant 874, Epoch 400, NLL=29.5939, omega=0.0794, tau=0.1158, condition=regret_early
# Participant 874, Epoch 500, NLL=29.5939, omega=0.0794, tau=0.1158, condition=regret_early
# Participant 765, Epoch 1, NLL=31.3041, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 765, Epoch 100, NLL=29.2689, omega=0.2066, tau=0.1996, condition=regret_early
# Participant 765, Epoch 200, NLL=28.6884, omega=0.1055, tau=0.1423, condition=regret_early
# Participant 765, Epoch 300, NLL=28.6399, omega=0.0763, tau=0.1442, condition=regret_early
# Participant 765, Epoch 400, NLL=28.6248, omega=0.0624, tau=0.1453, condition=regret_early
# Participant 765, Epoch 500, NLL=28.6184, omega=0.0542, tau=0.1460, condition=regret_early
# Participant 789, Epoch 1, NLL=31.8920, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 789, Epoch 100, NLL=30.6785, omega=0.1974, tau=0.2110, condition=regret_early
# Participant 789, Epoch 200, NLL=30.2360, omega=0.0912, tau=0.1715, condition=regret_early
# Participant 789, Epoch 300, NLL=30.1642, omega=0.0627, tau=0.1699, condition=regret_early
# Participant 789, Epoch 400, NLL=30.1427, omega=0.0499, tau=0.1699, condition=regret_early
# Participant 789, Epoch 500, NLL=30.1339, omega=0.0427, tau=0.1702, condition=regret_early
# Participant 826, Epoch 1, NLL=31.5925, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 826, Epoch 100, NLL=30.1077, omega=0.2298, tau=0.2099, condition=regret_early
# Participant 826, Epoch 200, NLL=30.0472, omega=0.2279, tau=0.1802, condition=regret_early
# Participant 826, Epoch 300, NLL=30.0465, omega=0.2364, tau=0.1776, condition=regret_early
# Participant 826, Epoch 400, NLL=30.0465, omega=0.2381, tau=0.1771, condition=regret_early
# Participant 826, Epoch 500, NLL=30.0465, omega=0.2382, tau=0.1770, condition=regret_early
# Participant 757, Epoch 1, NLL=29.5526, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 757, Epoch 100, NLL=25.8023, omega=0.2236, tau=0.2053, condition=regret_early
# Participant 757, Epoch 200, NLL=25.4248, omega=0.2360, tau=0.1559, condition=regret_early
# Participant 757, Epoch 300, NLL=25.4104, omega=0.2633, tau=0.1487, condition=regret_early
# Participant 757, Epoch 400, NLL=25.4100, omega=0.2685, tau=0.1474, condition=regret_early
# Participant 757, Epoch 500, NLL=25.4100, omega=0.2689, tau=0.1473, condition=regret_early
# Participant 701, Epoch 1, NLL=30.8446, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 701, Epoch 100, NLL=29.5831, omega=1.0044, tau=0.2108, condition=regret_early
# Participant 701, Epoch 200, NLL=29.2519, omega=1.4560, tau=0.1346, condition=regret_early
# Participant 701, Epoch 300, NLL=29.2518, omega=1.4644, tau=0.1337, condition=regret_early
# Participant 701, Epoch 400, NLL=29.2518, omega=1.4644, tau=0.1337, condition=regret_early
# Participant 701, Epoch 500, NLL=29.2518, omega=1.4644, tau=0.1337, condition=regret_early
# Participant 737, Epoch 1, NLL=29.8731, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 737, Epoch 100, NLL=26.2395, omega=0.2520, tau=0.1986, condition=regret_early
# Participant 737, Epoch 200, NLL=23.0123, omega=0.6262, tau=0.0846, condition=regret_early
# Participant 737, Epoch 300, NLL=19.7272, omega=1.2510, tau=0.0331, condition=regret_early
# Participant 737, Epoch 400, NLL=18.9871, omega=1.5612, tau=0.0210, condition=regret_early
# Participant 737, Epoch 500, NLL=18.9838, omega=1.5796, tau=0.0204, condition=regret_early
# Participant 719, Epoch 1, NLL=29.5613, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 719, Epoch 100, NLL=24.6408, omega=0.2158, tau=0.1918, condition=regret_early
# Participant 719, Epoch 200, NLL=21.7957, omega=0.3470, tau=0.0906, condition=regret_early
# Participant 719, Epoch 300, NLL=21.2189, omega=0.4970, tau=0.0641, condition=regret_early
# Participant 719, Epoch 400, NLL=21.2152, omega=0.5078, tau=0.0624, condition=regret_early
# Participant 719, Epoch 500, NLL=21.2152, omega=0.5078, tau=0.0624, condition=regret_early
# Participant 728, Epoch 1, NLL=28.8939, omega=0.4961, tau=0.4961, condition=regret_early
# Participant 728, Epoch 100, NLL=26.5045, omega=0.2285, tau=0.2444, condition=regret_early
# Participant 728, Epoch 200, NLL=26.3372, omega=0.1455, tau=0.2520, condition=regret_early
# Participant 728, Epoch 300, NLL=26.2638, omega=0.1027, tau=0.2607, condition=regret_early
# Participant 728, Epoch 400, NLL=26.2270, omega=0.0781, tau=0.2662, condition=regret_early
# Participant 728, Epoch 500, NLL=26.2060, omega=0.0624, tau=0.2700, condition=regret_early
# Participant 713, Epoch 1, NLL=30.7257, omega=0.5039, tau=0.4961, condition=regret_early
# Participant 713, Epoch 100, NLL=27.4770, omega=1.0320, tau=0.1867, condition=regret_early
# Participant 713, Epoch 200, NLL=20.6970, omega=1.5576, tau=0.0510, condition=regret_early
# Participant 713, Epoch 300, NLL=18.7745, omega=1.9670, tau=0.0263, condition=regret_early
# Participant 713, Epoch 400, NLL=18.7323, omega=2.1089, tau=0.0239, condition=regret_early
# Participant 713, Epoch 500, NLL=18.7320, omega=2.1232, tau=0.0237, condition=regret_early
# Participant 710, Epoch 1, NLL=33.8777, omega=0.4961, tau=0.5039, condition=regret_early
# Participant 710, Epoch 100, NLL=29.6532, omega=0.2093, tau=0.3748, condition=regret_early
# Participant 710, Epoch 200, NLL=8.5567, omega=0.0573, tau=0.0616, condition=regret_early
# Participant 710, Epoch 300, NLL=5.3177, omega=0.0369, tau=0.0334, condition=regret_early
# Participant 710, Epoch 400, NLL=5.2184, omega=0.0320, tau=0.0313, condition=regret_early
# Participant 710, Epoch 500, NLL=5.1801, omega=0.0288, tau=0.0317, condition=regret_early
# Participant 716, Epoch 1, NLL=31.6297, omega=0.5039, tau=0.4961, condition=regret_early
# Participant 716, Epoch 100, NLL=31.3435, omega=1.0951, tau=0.2711, condition=regret_early
# Participant 716, Epoch 200, NLL=31.3409, omega=1.2107, tau=0.2589, condition=regret_early
# Participant 716, Epoch 300, NLL=31.3409, omega=1.2101, tau=0.2590, condition=regret_early
# Participant 716, Epoch 400, NLL=31.3409, omega=1.2101, tau=0.2590, condition=regret_early
# Participant 716, Epoch 500, NLL=31.3409, omega=1.2101, tau=0.2590, condition=regret_early
# Participant 738, Epoch 1, NLL=28.4411, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 738, Epoch 100, NLL=26.0389, omega=0.3749, tau=0.2246, condition=regret_late
# Participant 738, Epoch 200, NLL=25.2392, omega=0.9046, tau=0.1426, condition=regret_late
# Participant 738, Epoch 300, NLL=25.1337, omega=1.2246, tau=0.1203, condition=regret_late
# Participant 738, Epoch 400, NLL=25.1290, omega=1.3097, tau=0.1160, condition=regret_late
# Participant 738, Epoch 500, NLL=25.1289, omega=1.3234, tau=0.1153, condition=regret_late
# Participant 711, Epoch 1, NLL=25.5723, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 711, Epoch 100, NLL=18.1572, omega=0.2126, tau=0.2036, condition=regret_late
# Participant 711, Epoch 200, NLL=16.3054, omega=0.1294, tau=0.1341, condition=regret_late
# Participant 711, Epoch 300, NLL=16.2449, omega=0.1017, tau=0.1371, condition=regret_late
# Participant 711, Epoch 400, NLL=16.2029, omega=0.0814, tau=0.1396, condition=regret_late
# Participant 711, Epoch 500, NLL=16.1735, omega=0.0664, tau=0.1414, condition=regret_late
# Participant 717, Epoch 1, NLL=30.0937, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 717, Epoch 100, NLL=19.6461, omega=0.1926, tau=0.1736, condition=regret_late
# Participant 717, Epoch 200, NLL=7.7076, omega=0.0766, tau=0.0604, condition=regret_late
# Participant 717, Epoch 300, NLL=7.1018, omega=0.0543, tau=0.0545, condition=regret_late
# Participant 717, Epoch 400, NLL=6.9243, omega=0.0433, tau=0.0568, condition=regret_late
# Participant 717, Epoch 500, NLL=6.8162, omega=0.0358, tau=0.0585, condition=regret_late
# Participant 744, Epoch 1, NLL=29.6408, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 744, Epoch 100, NLL=18.2724, omega=0.1950, tau=0.1744, condition=regret_late
# Participant 744, Epoch 200, NLL=5.1698, omega=0.0835, tau=0.0572, condition=regret_late
# Participant 744, Epoch 300, NLL=3.5733, omega=0.0587, tau=0.0379, condition=regret_late
# Participant 744, Epoch 400, NLL=3.2081, omega=0.0464, tau=0.0314, condition=regret_late
# Participant 744, Epoch 500, NLL=3.0368, omega=0.0380, tau=0.0279, condition=regret_late
# Participant 714, Epoch 1, NLL=28.1426, omega=0.4961, tau=0.4961, condition=regret_late
# Participant 714, Epoch 100, NLL=19.9174, omega=0.2072, tau=0.1871, condition=regret_late
# Participant 714, Epoch 200, NLL=12.1934, omega=0.1602, tau=0.0691, condition=regret_late
# Participant 714, Epoch 300, NLL=9.3944, omega=0.3908, tau=0.0414, condition=regret_late
# Participant 714, Epoch 400, NLL=8.4908, omega=0.4908, tau=0.0281, condition=regret_late
# Participant 714, Epoch 500, NLL=8.4390, omega=0.5023, tau=0.0254, condition=regret_late
# Training complete. Fitted parameters saved to fitted_parameters.csv

# %%
results_df = pd.DataFrame(all_results)
results_df.to_csv('regret_1_sim.csv', index=False)

# %%
print(results_df.groupby("condition")["omega"].describe())
# Out:
#               count      mean       std       min       25%       50%  \
# condition
# control        56.0  0.000000  0.000000  0.000000  0.000000  0.000000
# regret_early   60.0  0.961966  1.414525  0.009352  0.045548  0.171793
# regret_late    59.0  0.551960  1.096354  0.007603  0.029389  0.062883
#
#                    75%       max
# condition
# control       0.000000  0.000000
# regret_early  1.229877  4.880089
# regret_late   0.188459  4.646651

# %%
print(results_df.groupby("condition")["tau"].describe())
# Out:
#               count      mean       std       min       25%       50%  \
# condition
# control        56.0  0.250853  0.236838  0.016771  0.089015  0.164758
# regret_early   60.0  0.166594  0.223225  0.018540  0.071478  0.121080
# regret_late    59.0  0.283661  0.387755  0.019137  0.060485  0.112862
#
#                    75%       max
# condition
# control       0.321055  1.255719
# regret_early  0.169163  1.393482
# regret_late   0.302521  1.575055

# %% [markdown]
# ## CS

# %%
class RegretModel(nn.Module):
    def __init__(self, condition, initial_omega=0.5, initial_tau=0.5, kappa=1.0):
        """
        - If condition is 'control', omega is fixed at 0 and is not learned.
        - For regret conditions ('regret_early' or 'regret_late'), omega is learnable.
        """
        super().__init__()
        self.condition = condition
        self.softplus = nn.Softplus()
        self.kappa = kappa 

        def softplus_inverse(x):
            return math.log(math.exp(x) - 1.0)

        if condition == "control":
            self.log_omega = nn.Parameter(torch.tensor(float("-inf"), dtype=torch.float32), requires_grad=False)  
        else:
            init_log_omega = softplus_inverse(initial_omega)
            self.log_omega = nn.Parameter(torch.tensor(init_log_omega, dtype=torch.float32))

        init_log_tau = softplus_inverse(initial_tau)
        self.log_tau = nn.Parameter(torch.tensor(init_log_tau, dtype=torch.float32))

    def forward(self):
        """ Returns omega and tau. """
        omega = self.softplus(self.log_omega) if self.condition != "control" else torch.tensor(0.0, dtype=torch.float32)
        tau = self.softplus(self.log_tau) 
        return omega, tau
    
    def log_likelihood(self, participant_df):
        """
        Computes the negative log likelihood for a single participant's data.
        """
        omega, tau = self.forward()
        num_arms = 3

        alpha = torch.ones(num_arms, dtype=torch.float32, requires_grad=True)
        beta = torch.ones(num_arms, dtype=torch.float32, requires_grad=True)

        df_sorted = participant_df.sort_values('trial_index')
        nll = torch.tensor(0.0, dtype=torch.float32, requires_grad=True)

        for _, row in df_sorted.iterrows():
            choice = int(row['choice'])
            points = int(row['points'])
            trial_index = int(row['trial_index'])

            p_est = alpha / (alpha + beta)
            numerators = torch.exp(p_est / tau)
            probs = numerators / torch.sum(numerators)
            p_chosen = probs[choice]
            nll = nll - torch.log(p_chosen + 1e-12)

            alpha = alpha.clone()
            beta = beta.clone()

            if points == 1:
                alpha[choice] += 1.0
            else:
                beta[choice] += 1.0

                if (self.condition == 'regret_early' and trial_index <= 30 and points == 0) or \
                   (self.condition == 'regret_late' and trial_index > 30 and points == 0):
                    
                    p_est_np = (alpha / (alpha + beta)).detach().cpu().numpy()
                    p_est_np = np.clip(p_est_np, 1e-6, 1 - 1e-6) 

                    alpha = alpha.clone()  
                    for arm_i in range(num_arms):
                        if arm_i != choice:
                            probs_vec = np.array([1 - p_est_np[arm_i], p_est_np[arm_i]])
                            probs_vec /= probs_vec.sum() 
                            counterfactual_outcome = np.random.choice([0, 1], p=probs_vec)

                            if counterfactual_outcome == 1:
                                alpha[arm_i] += self.kappa * omega
                            else:
                                beta[arm_i] += self.kappa * omega

        return nll

# -----------------------------------------------------------------------------
# Training loop for each participant
# -----------------------------------------------------------------------------
unique_participants = df['workerid'].unique()

num_epochs = 500
learning_rate = 0.01  

print_interval = 100

all_results = []

for participant in unique_participants:
    participant_df = df[df['workerid'] == participant]
    participant_condition = participant_df['condition'].iloc[0]

    model = RegretModel(condition=participant_condition, initial_omega=0.5, initial_tau=0.5, kappa=1.0)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    for epoch in range(num_epochs):
        optimizer.zero_grad()
        nll = model.log_likelihood(participant_df)
        nll.backward()

        optimizer.step()

        if (epoch + 1) % print_interval == 0 or epoch == 0:
            with torch.no_grad():
                omega_val, tau_val = model.forward()
                print(f"Participant={participant}, Epoch={epoch+1}, "
                      f"NLL={nll.item():.4f}, "
                      f"omega={omega_val.item():.4f}, tau={tau_val.item():.4f}, condition={participant_condition}")

    final_omega, final_tau = model.forward()
    final_nll = model.log_likelihood(participant_df).item()

    all_results.append({
        'participant': participant,
        'condition': participant_condition,
        'omega': final_omega.item(),
        'tau': final_tau.item(),
        'nll': final_nll
    })

results_df = pd.DataFrame(all_results)
# Out:
# Participant=860, Epoch=1, NLL=29.6243, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=860, Epoch=100, NLL=27.7998, omega=0.2628, tau=0.2726, condition=regret_late
# Participant=860, Epoch=200, NLL=28.2695, omega=0.1755, tau=0.2714, condition=regret_late
# Participant=860, Epoch=300, NLL=27.7748, omega=0.1393, tau=0.2690, condition=regret_late
# Participant=860, Epoch=400, NLL=27.3613, omega=0.1130, tau=0.2684, condition=regret_late
# Participant=860, Epoch=500, NLL=27.6699, omega=0.0879, tau=0.2683, condition=regret_late
# Participant=835, Epoch=1, NLL=22.1503, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=835, Epoch=100, NLL=9.8088, omega=0.3230, tau=0.1990, condition=regret_late
# Participant=835, Epoch=200, NLL=3.1783, omega=0.1940, tau=0.0742, condition=regret_late
# Participant=835, Epoch=300, NLL=3.9752, omega=0.1404, tau=0.0475, condition=regret_late
# Participant=835, Epoch=400, NLL=2.6249, omega=0.1101, tau=0.0386, condition=regret_late
# Participant=835, Epoch=500, NLL=2.5075, omega=0.0919, tau=0.0341, condition=regret_late
# Participant=753, Epoch=1, NLL=33.6525, omega=0.4961, tau=0.5039, condition=regret_late
# Participant=753, Epoch=100, NLL=33.2642, omega=0.4212, tau=0.8218, condition=regret_late
# Participant=753, Epoch=200, NLL=33.2615, omega=0.3957, tau=1.0803, condition=regret_late
# Participant=753, Epoch=300, NLL=33.1669, omega=0.3533, tau=1.3263, condition=regret_late
# Participant=753, Epoch=400, NLL=33.0147, omega=0.3452, tau=1.5192, condition=regret_late
# Participant=753, Epoch=500, NLL=32.9972, omega=0.3365, tau=1.6991, condition=regret_late
# Participant=833, Epoch=1, NLL=32.6637, omega=0.4961, tau=0.5039, condition=regret_late
# Participant=833, Epoch=100, NLL=32.2775, omega=0.3515, tau=0.5581, condition=regret_late
# Participant=833, Epoch=200, NLL=32.7822, omega=0.2628, tau=0.5699, condition=regret_late
# Participant=833, Epoch=300, NLL=32.7494, omega=0.2146, tau=0.5207, condition=regret_late
# Participant=833, Epoch=400, NLL=32.0012, omega=0.1757, tau=0.4931, condition=regret_late
# Participant=833, Epoch=500, NLL=32.1559, omega=0.1550, tau=0.5042, condition=regret_late
# Participant=841, Epoch=1, NLL=32.4019, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=841, Epoch=100, NLL=34.9444, omega=0.3990, tau=0.6215, condition=regret_late
# Participant=841, Epoch=200, NLL=31.9117, omega=0.3792, tau=0.6543, condition=regret_late
# Participant=841, Epoch=300, NLL=32.2035, omega=0.3308, tau=0.7170, condition=regret_late
# Participant=841, Epoch=400, NLL=32.1230, omega=0.2905, tau=0.7588, condition=regret_late
# Participant=841, Epoch=500, NLL=31.3790, omega=0.2484, tau=0.8020, condition=regret_late
# Participant=806, Epoch=1, NLL=27.8668, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=806, Epoch=100, NLL=27.8476, omega=0.3077, tau=0.3114, condition=regret_late
# Participant=806, Epoch=200, NLL=27.4584, omega=0.2177, tau=0.3128, condition=regret_late
# Participant=806, Epoch=300, NLL=26.9995, omega=0.1831, tau=0.3177, condition=regret_late
# Participant=806, Epoch=400, NLL=27.7301, omega=0.1465, tau=0.3145, condition=regret_late
# Participant=806, Epoch=500, NLL=27.0694, omega=0.1315, tau=0.3139, condition=regret_late
# Participant=811, Epoch=1, NLL=25.4136, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=811, Epoch=100, NLL=16.5856, omega=0.2511, tau=0.2010, condition=regret_late
# Participant=811, Epoch=200, NLL=11.7063, omega=0.1527, tau=0.1106, condition=regret_late
# Participant=811, Epoch=300, NLL=11.5495, omega=0.1166, tau=0.1033, condition=regret_late
# Participant=811, Epoch=400, NLL=11.5855, omega=0.0957, tau=0.1026, condition=regret_late
# Participant=811, Epoch=500, NLL=12.0879, omega=0.0796, tau=0.1054, condition=regret_late
# Participant=823, Epoch=1, NLL=28.1242, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=823, Epoch=100, NLL=21.7554, omega=0.2755, tau=0.2007, condition=regret_late
# Participant=823, Epoch=200, NLL=15.1275, omega=0.1332, tau=0.0837, condition=regret_late
# Participant=823, Epoch=300, NLL=14.7201, omega=0.0889, tau=0.0801, condition=regret_late
# Participant=823, Epoch=400, NLL=14.2847, omega=0.0671, tau=0.0801, condition=regret_late
# Participant=823, Epoch=500, NLL=14.2620, omega=0.0562, tau=0.0805, condition=regret_late
# Participant=764, Epoch=1, NLL=32.8852, omega=0.4961, tau=0.5039, condition=regret_late
# Participant=764, Epoch=100, NLL=30.7310, omega=0.3239, tau=0.5220, condition=regret_late
# Participant=764, Epoch=200, NLL=31.5141, omega=0.2126, tau=0.5560, condition=regret_late
# Participant=764, Epoch=300, NLL=31.1133, omega=0.1612, tau=0.5583, condition=regret_late
# Participant=764, Epoch=400, NLL=31.3730, omega=0.1254, tau=0.5628, condition=regret_late
# Participant=764, Epoch=500, NLL=31.3744, omega=0.0940, tau=0.5572, condition=regret_late
# Participant=863, Epoch=1, NLL=26.3731, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=863, Epoch=100, NLL=12.9452, omega=0.3474, tau=0.2058, condition=regret_late
# Participant=863, Epoch=200, NLL=3.2577, omega=0.1939, tau=0.0731, condition=regret_late
# Participant=863, Epoch=300, NLL=1.3392, omega=0.1304, tau=0.0444, condition=regret_late
# Participant=863, Epoch=400, NLL=1.2920, omega=0.1131, tau=0.0362, condition=regret_late
# Participant=863, Epoch=500, NLL=1.1612, omega=0.1059, tau=0.0324, condition=regret_late
# Participant=780, Epoch=1, NLL=28.9615, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=780, Epoch=100, NLL=23.8729, omega=0.3023, tau=0.2369, condition=regret_late
# Participant=780, Epoch=200, NLL=24.6488, omega=0.1822, tau=0.2207, condition=regret_late
# Participant=780, Epoch=300, NLL=24.7281, omega=0.1227, tau=0.2195, condition=regret_late
# Participant=780, Epoch=400, NLL=24.4904, omega=0.0865, tau=0.2239, condition=regret_late
# Participant=780, Epoch=500, NLL=24.8197, omega=0.0726, tau=0.2211, condition=regret_late
# Participant=770, Epoch=1, NLL=31.9229, omega=0.5039, tau=0.5039, condition=regret_late
# Participant=770, Epoch=100, NLL=31.7360, omega=0.3939, tau=0.6823, condition=regret_late
# Participant=770, Epoch=200, NLL=31.9291, omega=0.3523, tau=0.7032, condition=regret_late
# Participant=770, Epoch=300, NLL=31.7870, omega=0.3018, tau=0.6931, condition=regret_late
# Participant=770, Epoch=400, NLL=31.9406, omega=0.3006, tau=0.6928, condition=regret_late
# Participant=770, Epoch=500, NLL=31.5294, omega=0.2612, tau=0.6893, condition=regret_late
# Participant=795, Epoch=1, NLL=25.8059, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=795, Epoch=100, NLL=19.7537, omega=0.2876, tau=0.2054, condition=regret_late
# Participant=795, Epoch=200, NLL=9.9186, omega=0.1463, tau=0.0738, condition=regret_late
# Participant=795, Epoch=300, NLL=7.2150, omega=0.0877, tau=0.0535, condition=regret_late
# Participant=795, Epoch=400, NLL=7.7375, omega=0.0665, tau=0.0499, condition=regret_late
# Participant=795, Epoch=500, NLL=6.4906, omega=0.0552, tau=0.0499, condition=regret_late
# Participant=813, Epoch=1, NLL=30.4986, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=813, Epoch=100, NLL=23.1266, omega=0.2650, tau=0.2368, condition=regret_late
# Participant=813, Epoch=200, NLL=15.4904, omega=0.1216, tau=0.0765, condition=regret_late
# Participant=813, Epoch=300, NLL=13.5353, omega=0.0653, tau=0.0506, condition=regret_late
# Participant=813, Epoch=400, NLL=15.6083, omega=0.0477, tau=0.0500, condition=regret_late
# Participant=813, Epoch=500, NLL=15.7005, omega=0.0384, tau=0.0495, condition=regret_late
# Participant=758, Epoch=1, NLL=22.7937, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=758, Epoch=100, NLL=17.1597, omega=0.2860, tau=0.2098, condition=regret_late
# Participant=758, Epoch=200, NLL=16.3519, omega=0.1916, tau=0.1350, condition=regret_late
# Participant=758, Epoch=300, NLL=15.6489, omega=0.1696, tau=0.1339, condition=regret_late
# Participant=758, Epoch=400, NLL=15.6397, omega=0.1416, tau=0.1339, condition=regret_late
# Participant=758, Epoch=500, NLL=16.1743, omega=0.1140, tau=0.1335, condition=regret_late
# Participant=786, Epoch=1, NLL=26.0558, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=786, Epoch=100, NLL=23.7067, omega=0.3304, tau=0.2086, condition=regret_late
# Participant=786, Epoch=200, NLL=21.3698, omega=0.1796, tau=0.1289, condition=regret_late
# Participant=786, Epoch=300, NLL=21.8609, omega=0.1313, tau=0.1327, condition=regret_late
# Participant=786, Epoch=400, NLL=22.0600, omega=0.1069, tau=0.1295, condition=regret_late
# Participant=786, Epoch=500, NLL=22.1096, omega=0.1042, tau=0.1280, condition=regret_late
# Participant=831, Epoch=1, NLL=28.2643, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=831, Epoch=100, NLL=28.1759, omega=0.2606, tau=0.2696, condition=regret_late
# Participant=831, Epoch=200, NLL=26.0863, omega=0.1143, tau=0.1076, condition=regret_late
# Participant=831, Epoch=300, NLL=16.9208, omega=0.0582, tau=0.0745, condition=regret_late
# Participant=831, Epoch=400, NLL=17.7418, omega=0.0418, tau=0.0661, condition=regret_late
# Participant=831, Epoch=500, NLL=23.1646, omega=0.0319, tau=0.0671, condition=regret_late
# Participant=800, Epoch=1, NLL=34.0832, omega=0.4961, tau=0.5039, condition=regret_late
# Participant=800, Epoch=100, NLL=33.6543, omega=0.3540, tau=0.8042, condition=regret_late
# Participant=800, Epoch=200, NLL=32.4685, omega=0.2959, tau=1.0044, condition=regret_late
# Participant=800, Epoch=300, NLL=33.3256, omega=0.2528, tau=1.1657, condition=regret_late
# Participant=800, Epoch=400, NLL=33.4139, omega=0.2240, tau=1.3021, condition=regret_late
# Participant=800, Epoch=500, NLL=33.1107, omega=0.1935, tau=1.4381, condition=regret_late
# Participant=762, Epoch=1, NLL=24.5653, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=762, Epoch=100, NLL=17.4758, omega=0.2613, tau=0.2047, condition=regret_late
# Participant=762, Epoch=200, NLL=13.5020, omega=0.1230, tau=0.0990, condition=regret_late
# Participant=762, Epoch=300, NLL=13.7398, omega=0.0861, tau=0.0881, condition=regret_late
# Participant=762, Epoch=400, NLL=15.7633, omega=0.0695, tau=0.0882, condition=regret_late
# Participant=762, Epoch=500, NLL=14.5345, omega=0.0532, tau=0.0904, condition=regret_late
# Participant=815, Epoch=1, NLL=26.3256, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=815, Epoch=100, NLL=26.3561, omega=0.3729, tau=0.3428, condition=regret_late
# Participant=815, Epoch=200, NLL=29.5398, omega=0.2376, tau=0.1925, condition=regret_late
# Participant=815, Epoch=300, NLL=29.1488, omega=0.1308, tau=0.0775, condition=regret_late
# Participant=815, Epoch=400, NLL=15.2652, omega=0.0633, tau=0.0423, condition=regret_late
# Participant=815, Epoch=500, NLL=14.1406, omega=0.0419, tau=0.0398, condition=regret_late
# Participant=875, Epoch=1, NLL=23.4261, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=875, Epoch=100, NLL=14.3355, omega=0.4506, tau=0.2215, condition=regret_late
# Participant=875, Epoch=200, NLL=13.0627, omega=0.2480, tau=0.0980, condition=regret_late
# Participant=875, Epoch=300, NLL=18.7266, omega=0.1583, tau=0.0688, condition=regret_late
# Participant=875, Epoch=400, NLL=13.2670, omega=0.1180, tau=0.0665, condition=regret_late
# Participant=875, Epoch=500, NLL=14.9333, omega=0.1024, tau=0.0658, condition=regret_late
# Participant=869, Epoch=1, NLL=31.0905, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=869, Epoch=100, NLL=28.0866, omega=0.2829, tau=0.3121, condition=regret_late
# Participant=869, Epoch=200, NLL=28.6796, omega=0.1735, tau=0.3054, condition=regret_late
# Participant=869, Epoch=300, NLL=28.5701, omega=0.1145, tau=0.3107, condition=regret_late
# Participant=869, Epoch=400, NLL=28.9330, omega=0.0840, tau=0.2969, condition=regret_late
# Participant=869, Epoch=500, NLL=29.2545, omega=0.0649, tau=0.2954, condition=regret_late
# Participant=778, Epoch=1, NLL=30.0109, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=778, Epoch=100, NLL=30.2759, omega=0.3566, tau=0.4618, condition=regret_late
# Participant=778, Epoch=200, NLL=30.1712, omega=0.3209, tau=0.4659, condition=regret_late
# Participant=778, Epoch=300, NLL=30.4406, omega=0.2465, tau=0.4705, condition=regret_late
# Participant=778, Epoch=400, NLL=30.7699, omega=0.2063, tau=0.4680, condition=regret_late
# Participant=778, Epoch=500, NLL=30.5904, omega=0.1888, tau=0.4648, condition=regret_late
# Participant=842, Epoch=1, NLL=27.8468, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=842, Epoch=100, NLL=19.8353, omega=0.2408, tau=0.2098, condition=regret_late
# Participant=842, Epoch=200, NLL=19.4264, omega=0.1081, tau=0.1158, condition=regret_late
# Participant=842, Epoch=300, NLL=19.4770, omega=0.0675, tau=0.1133, condition=regret_late
# Participant=842, Epoch=400, NLL=18.2251, omega=0.0474, tau=0.1122, condition=regret_late
# Participant=842, Epoch=500, NLL=17.7213, omega=0.0356, tau=0.1116, condition=regret_late
# Participant=766, Epoch=1, NLL=26.8586, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=766, Epoch=100, NLL=14.9959, omega=0.3899, tau=0.1992, condition=regret_late
# Participant=766, Epoch=200, NLL=5.5084, omega=0.2246, tau=0.0786, condition=regret_late
# Participant=766, Epoch=300, NLL=1.4938, omega=0.1690, tau=0.0510, condition=regret_late
# Participant=766, Epoch=400, NLL=1.4307, omega=0.1446, tau=0.0410, condition=regret_late
# Participant=766, Epoch=500, NLL=1.3227, omega=0.1315, tau=0.0356, condition=regret_late
# Participant=844, Epoch=1, NLL=34.0258, omega=0.4961, tau=0.5039, condition=regret_late
# Participant=844, Epoch=100, NLL=32.8270, omega=0.3210, tau=0.6553, condition=regret_late
# Participant=844, Epoch=200, NLL=32.3454, omega=0.2163, tau=0.7367, condition=regret_late
# Participant=844, Epoch=300, NLL=31.7898, omega=0.1552, tau=0.7255, condition=regret_late
# Participant=844, Epoch=400, NLL=32.8143, omega=0.1127, tau=0.6735, condition=regret_late
# Participant=844, Epoch=500, NLL=32.3801, omega=0.0830, tau=0.6016, condition=regret_late
# Participant=776, Epoch=1, NLL=35.5382, omega=0.4961, tau=0.5039, condition=regret_late
# Participant=776, Epoch=100, NLL=33.0506, omega=0.4458, tau=0.8452, condition=regret_late
# Participant=776, Epoch=200, NLL=33.2343, omega=0.4651, tau=1.1043, condition=regret_late
# Participant=776, Epoch=300, NLL=33.0014, omega=0.5061, tau=1.3182, condition=regret_late
# Participant=776, Epoch=400, NLL=33.0062, omega=0.5713, tau=1.4961, condition=regret_late
# Participant=776, Epoch=500, NLL=32.9510, omega=0.5703, tau=1.6853, condition=regret_late
# Participant=867, Epoch=1, NLL=22.8600, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=867, Epoch=100, NLL=19.3488, omega=0.2828, tau=0.2011, condition=regret_late
# Participant=867, Epoch=200, NLL=14.8108, omega=0.1526, tau=0.0883, condition=regret_late
# Participant=867, Epoch=300, NLL=14.1010, omega=0.0977, tau=0.0779, condition=regret_late
# Participant=867, Epoch=400, NLL=13.5386, omega=0.0716, tau=0.0788, condition=regret_late
# Participant=867, Epoch=500, NLL=13.3530, omega=0.0592, tau=0.0789, condition=regret_late
# Participant=821, Epoch=1, NLL=29.7825, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=821, Epoch=100, NLL=23.3697, omega=0.2263, tau=0.1922, condition=regret_late
# Participant=821, Epoch=200, NLL=15.3325, omega=0.1034, tau=0.0782, condition=regret_late
# Participant=821, Epoch=300, NLL=15.8407, omega=0.0735, tau=0.0742, condition=regret_late
# Participant=821, Epoch=400, NLL=15.5718, omega=0.0601, tau=0.0732, condition=regret_late
# Participant=821, Epoch=500, NLL=17.1132, omega=0.0481, tau=0.0740, condition=regret_late
# Participant=871, Epoch=1, NLL=32.3224, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=871, Epoch=100, NLL=29.8567, omega=0.2817, tau=0.3132, condition=regret_late
# Participant=871, Epoch=200, NLL=29.6402, omega=0.1857, tau=0.2791, condition=regret_late
# Participant=871, Epoch=300, NLL=30.7143, omega=0.1410, tau=0.2848, condition=regret_late
# Participant=871, Epoch=400, NLL=30.2823, omega=0.1059, tau=0.2774, condition=regret_late
# Participant=871, Epoch=500, NLL=29.4816, omega=0.0786, tau=0.2758, condition=regret_late
# Participant=838, Epoch=1, NLL=25.8581, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=838, Epoch=100, NLL=17.3210, omega=0.2545, tau=0.1964, condition=regret_late
# Participant=838, Epoch=200, NLL=10.0776, omega=0.1221, tau=0.0728, condition=regret_late
# Participant=838, Epoch=300, NLL=8.8753, omega=0.0809, tau=0.0517, condition=regret_late
# Participant=838, Epoch=400, NLL=8.8317, omega=0.0655, tau=0.0477, condition=regret_late
# Participant=838, Epoch=500, NLL=8.8172, omega=0.0539, tau=0.0481, condition=regret_late
# Participant=854, Epoch=1, NLL=30.5427, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=854, Epoch=100, NLL=26.9787, omega=0.2402, tau=0.2126, condition=regret_late
# Participant=854, Epoch=200, NLL=27.2750, omega=0.1367, tau=0.1441, condition=regret_late
# Participant=854, Epoch=300, NLL=27.6039, omega=0.0954, tau=0.1478, condition=regret_late
# Participant=854, Epoch=400, NLL=27.8302, omega=0.0747, tau=0.1405, condition=regret_late
# Participant=854, Epoch=500, NLL=28.0681, omega=0.0581, tau=0.1438, condition=regret_late
# Participant=802, Epoch=1, NLL=31.1148, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=802, Epoch=100, NLL=29.2728, omega=0.3080, tau=0.3365, condition=regret_late
# Participant=802, Epoch=200, NLL=28.0279, omega=0.2130, tau=0.3172, condition=regret_late
# Participant=802, Epoch=300, NLL=28.7687, omega=0.1680, tau=0.3106, condition=regret_late
# Participant=802, Epoch=400, NLL=31.4568, omega=0.1374, tau=0.3162, condition=regret_late
# Participant=802, Epoch=500, NLL=28.8555, omega=0.1228, tau=0.3063, condition=regret_late
# Participant=827, Epoch=1, NLL=29.1862, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=827, Epoch=100, NLL=22.9252, omega=0.2739, tau=0.2140, condition=regret_late
# Participant=827, Epoch=200, NLL=18.9535, omega=0.1340, tau=0.1039, condition=regret_late
# Participant=827, Epoch=300, NLL=20.1382, omega=0.0805, tau=0.0959, condition=regret_late
# Participant=827, Epoch=400, NLL=19.7677, omega=0.0601, tau=0.0942, condition=regret_late
# Participant=827, Epoch=500, NLL=17.2112, omega=0.0450, tau=0.0957, condition=regret_late
# Participant=849, Epoch=1, NLL=31.5275, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=849, Epoch=100, NLL=28.2360, omega=0.3430, tau=0.2165, condition=regret_late
# Participant=849, Epoch=200, NLL=24.5618, omega=0.2088, tau=0.1267, condition=regret_late
# Participant=849, Epoch=300, NLL=24.3307, omega=0.1450, tau=0.1254, condition=regret_late
# Participant=849, Epoch=400, NLL=25.0530, omega=0.1151, tau=0.1258, condition=regret_late
# Participant=849, Epoch=500, NLL=24.9511, omega=0.0950, tau=0.1242, condition=regret_late
# Participant=856, Epoch=1, NLL=33.8336, omega=0.5039, tau=0.5039, condition=regret_late
# Participant=856, Epoch=100, NLL=34.5696, omega=0.5615, tau=0.8603, condition=regret_late
# Participant=856, Epoch=200, NLL=33.1072, omega=0.5772, tau=1.1387, condition=regret_late
# Participant=856, Epoch=300, NLL=32.9558, omega=0.6211, tau=1.3615, condition=regret_late
# Participant=856, Epoch=400, NLL=33.4824, omega=0.6659, tau=1.5569, condition=regret_late
# Participant=856, Epoch=500, NLL=33.3875, omega=0.7174, tau=1.7315, condition=regret_late
# Participant=797, Epoch=1, NLL=27.3024, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=797, Epoch=100, NLL=24.7489, omega=0.2487, tau=0.2181, condition=regret_late
# Participant=797, Epoch=200, NLL=22.9339, omega=0.1371, tau=0.1803, condition=regret_late
# Participant=797, Epoch=300, NLL=22.7229, omega=0.0928, tau=0.1795, condition=regret_late
# Participant=797, Epoch=400, NLL=22.6620, omega=0.0662, tau=0.1801, condition=regret_late
# Participant=797, Epoch=500, NLL=22.9084, omega=0.0494, tau=0.1813, condition=regret_late
# Participant=804, Epoch=1, NLL=30.3226, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=804, Epoch=100, NLL=29.4787, omega=0.2693, tau=0.3176, condition=regret_late
# Participant=804, Epoch=200, NLL=28.9292, omega=0.1677, tau=0.3112, condition=regret_late
# Participant=804, Epoch=300, NLL=29.0915, omega=0.1227, tau=0.3108, condition=regret_late
# Participant=804, Epoch=400, NLL=28.9974, omega=0.0917, tau=0.3125, condition=regret_late
# Participant=804, Epoch=500, NLL=29.0077, omega=0.0767, tau=0.3169, condition=regret_late
# Participant=752, Epoch=1, NLL=31.4881, omega=0.4961, tau=0.5039, condition=regret_late
# Participant=752, Epoch=100, NLL=31.5015, omega=0.3088, tau=0.5795, condition=regret_late
# Participant=752, Epoch=200, NLL=31.2855, omega=0.2266, tau=0.5657, condition=regret_late
# Participant=752, Epoch=300, NLL=31.4261, omega=0.1758, tau=0.5647, condition=regret_late
# Participant=752, Epoch=400, NLL=31.2413, omega=0.1545, tau=0.5714, condition=regret_late
# Participant=752, Epoch=500, NLL=31.0991, omega=0.1260, tau=0.5759, condition=regret_late
# Participant=861, Epoch=1, NLL=33.4189, omega=0.4961, tau=0.5039, condition=regret_late
# Participant=861, Epoch=100, NLL=33.4589, omega=0.3624, tau=0.7329, condition=regret_late
# Participant=861, Epoch=200, NLL=32.9726, omega=0.2818, tau=0.8958, condition=regret_late
# Participant=861, Epoch=300, NLL=32.6302, omega=0.2355, tau=0.9680, condition=regret_late
# Participant=861, Epoch=400, NLL=32.5531, omega=0.1948, tau=1.0282, condition=regret_late
# Participant=861, Epoch=500, NLL=32.8216, omega=0.1654, tau=1.0649, condition=regret_late
# Participant=817, Epoch=1, NLL=34.3938, omega=0.4961, tau=0.5039, condition=regret_late
# Participant=817, Epoch=100, NLL=28.2522, omega=0.2431, tau=0.2583, condition=regret_late
# Participant=817, Epoch=200, NLL=23.6251, omega=0.1125, tau=0.1185, condition=regret_late
# Participant=817, Epoch=300, NLL=24.4893, omega=0.0656, tau=0.1157, condition=regret_late
# Participant=817, Epoch=400, NLL=25.2206, omega=0.0478, tau=0.1140, condition=regret_late
# Participant=817, Epoch=500, NLL=25.1264, omega=0.0373, tau=0.1136, condition=regret_late
# Participant=858, Epoch=1, NLL=32.0571, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=858, Epoch=100, NLL=30.7633, omega=0.2864, tau=0.3835, condition=regret_late
# Participant=858, Epoch=200, NLL=30.3567, omega=0.1536, tau=0.1858, condition=regret_late
# Participant=858, Epoch=300, NLL=30.0456, omega=0.0761, tau=0.1265, condition=regret_late
# Participant=858, Epoch=400, NLL=28.2920, omega=0.0476, tau=0.1208, condition=regret_late
# Participant=858, Epoch=500, NLL=29.1257, omega=0.0344, tau=0.1199, condition=regret_late
# Participant=840, Epoch=1, NLL=28.9631, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=840, Epoch=100, NLL=26.8580, omega=0.3804, tau=0.2469, condition=regret_late
# Participant=840, Epoch=200, NLL=27.1761, omega=0.2114, tau=0.1303, condition=regret_late
# Participant=840, Epoch=300, NLL=24.7832, omega=0.1296, tau=0.1077, condition=regret_late
# Participant=840, Epoch=400, NLL=24.3336, omega=0.0884, tau=0.1084, condition=regret_late
# Participant=840, Epoch=500, NLL=24.5560, omega=0.0724, tau=0.1051, condition=regret_late
# Participant=774, Epoch=1, NLL=24.8383, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=774, Epoch=100, NLL=23.5436, omega=0.2945, tau=0.2254, condition=regret_late
# Participant=774, Epoch=200, NLL=21.0212, omega=0.1716, tau=0.1696, condition=regret_late
# Participant=774, Epoch=300, NLL=20.3044, omega=0.1300, tau=0.1676, condition=regret_late
# Participant=774, Epoch=400, NLL=20.3108, omega=0.1041, tau=0.1645, condition=regret_late
# Participant=774, Epoch=500, NLL=20.7355, omega=0.0843, tau=0.1659, condition=regret_late
# Participant=819, Epoch=1, NLL=25.6917, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=819, Epoch=100, NLL=23.3913, omega=0.3179, tau=0.2296, condition=regret_late
# Participant=819, Epoch=200, NLL=21.2055, omega=0.2067, tau=0.2005, condition=regret_late
# Participant=819, Epoch=300, NLL=21.7732, omega=0.1684, tau=0.1972, condition=regret_late
# Participant=819, Epoch=400, NLL=22.0007, omega=0.1224, tau=0.1957, condition=regret_late
# Participant=819, Epoch=500, NLL=21.6231, omega=0.1044, tau=0.1954, condition=regret_late
# Participant=807, Epoch=1, NLL=30.6110, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=807, Epoch=100, NLL=31.4429, omega=0.3071, tau=0.2752, condition=regret_late
# Participant=807, Epoch=200, NLL=22.7232, omega=0.1716, tau=0.1425, condition=regret_late
# Participant=807, Epoch=300, NLL=22.6315, omega=0.1058, tau=0.0945, condition=regret_late
# Participant=807, Epoch=400, NLL=21.6485, omega=0.0765, tau=0.0870, condition=regret_late
# Participant=807, Epoch=500, NLL=27.2410, omega=0.0593, tau=0.0866, condition=regret_late
# Participant=829, Epoch=1, NLL=28.1218, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=829, Epoch=100, NLL=30.2956, omega=0.3393, tau=0.4810, condition=regret_late
# Participant=829, Epoch=200, NLL=37.0557, omega=0.2326, tau=0.3774, condition=regret_late
# Participant=829, Epoch=300, NLL=25.3425, omega=0.1671, tau=0.2726, condition=regret_late
# Participant=829, Epoch=400, NLL=25.6444, omega=0.1098, tau=0.2074, condition=regret_late
# Participant=829, Epoch=500, NLL=31.9983, omega=0.0750, tau=0.1682, condition=regret_late
# Participant=792, Epoch=1, NLL=21.8372, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=792, Epoch=100, NLL=19.0672, omega=0.3647, tau=0.2081, condition=regret_late
# Participant=792, Epoch=200, NLL=4.3143, omega=0.1846, tau=0.0707, condition=regret_late
# Participant=792, Epoch=300, NLL=2.0144, omega=0.1152, tau=0.0388, condition=regret_late
# Participant=792, Epoch=400, NLL=1.2669, omega=0.0990, tau=0.0309, condition=regret_late
# Participant=792, Epoch=500, NLL=1.5539, omega=0.0874, tau=0.0265, condition=regret_late
# Participant=782, Epoch=1, NLL=24.5834, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=782, Epoch=100, NLL=17.9323, omega=0.3147, tau=0.2125, condition=regret_late
# Participant=782, Epoch=200, NLL=7.9398, omega=0.1597, tau=0.0688, condition=regret_late
# Participant=782, Epoch=300, NLL=4.9977, omega=0.0896, tau=0.0442, condition=regret_late
# Participant=782, Epoch=400, NLL=6.2048, omega=0.0636, tau=0.0406, condition=regret_late
# Participant=782, Epoch=500, NLL=6.5505, omega=0.0501, tau=0.0398, condition=regret_late
# Participant=873, Epoch=1, NLL=29.7696, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=873, Epoch=100, NLL=27.2169, omega=0.2772, tau=0.2321, condition=regret_late
# Participant=873, Epoch=200, NLL=26.5981, omega=0.1466, tau=0.1681, condition=regret_late
# Participant=873, Epoch=300, NLL=27.0421, omega=0.0964, tau=0.1635, condition=regret_late
# Participant=873, Epoch=400, NLL=26.7679, omega=0.0685, tau=0.1598, condition=regret_late
# Participant=873, Epoch=500, NLL=26.9217, omega=0.0505, tau=0.1608, condition=regret_late
# Participant=852, Epoch=1, NLL=24.0182, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=852, Epoch=100, NLL=12.6398, omega=0.3172, tau=0.2007, condition=regret_late
# Participant=852, Epoch=200, NLL=7.9266, omega=0.1902, tau=0.0880, condition=regret_late
# Participant=852, Epoch=300, NLL=5.1591, omega=0.1364, tau=0.0680, condition=regret_late
# Participant=852, Epoch=400, NLL=4.8958, omega=0.1084, tau=0.0651, condition=regret_late
# Participant=852, Epoch=500, NLL=5.3862, omega=0.0941, tau=0.0653, condition=regret_late
# Participant=865, Epoch=1, NLL=30.7501, omega=0.4961, tau=0.5039, condition=regret_late
# Participant=865, Epoch=100, NLL=28.4283, omega=0.3949, tau=0.3509, condition=regret_late
# Participant=865, Epoch=200, NLL=29.2778, omega=0.2948, tau=0.3502, condition=regret_late
# Participant=865, Epoch=300, NLL=29.5183, omega=0.2339, tau=0.3484, condition=regret_late
# Participant=865, Epoch=400, NLL=29.5159, omega=0.1832, tau=0.3427, condition=regret_late
# Participant=865, Epoch=500, NLL=28.2417, omega=0.1392, tau=0.3330, condition=regret_late
# Participant=772, Epoch=1, NLL=22.2508, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=772, Epoch=100, NLL=8.8803, omega=0.3425, tau=0.2009, condition=regret_late
# Participant=772, Epoch=200, NLL=3.2634, omega=0.2007, tau=0.0889, condition=regret_late
# Participant=772, Epoch=300, NLL=2.5805, omega=0.1471, tau=0.0609, condition=regret_late
# Participant=772, Epoch=400, NLL=2.1719, omega=0.1163, tau=0.0499, condition=regret_late
# Participant=772, Epoch=500, NLL=1.8886, omega=0.0992, tau=0.0429, condition=regret_late
# Participant=768, Epoch=1, NLL=32.8473, omega=0.5039, tau=0.5039, condition=regret_late
# Participant=768, Epoch=100, NLL=32.8992, omega=0.3757, tau=0.8030, condition=regret_late
# Participant=768, Epoch=200, NLL=32.8431, omega=0.2932, tau=0.9912, condition=regret_late
# Participant=768, Epoch=300, NLL=32.7384, omega=0.2297, tau=1.1087, condition=regret_late
# Participant=768, Epoch=400, NLL=32.7600, omega=0.1951, tau=1.1776, condition=regret_late
# Participant=768, Epoch=500, NLL=32.7522, omega=0.1748, tau=1.2219, condition=regret_late
# Participant=846, Epoch=1, NLL=31.3572, omega=0.5039, tau=0.5039, condition=regret_late
# Participant=846, Epoch=100, NLL=32.0928, omega=0.3687, tau=0.6466, condition=regret_late
# Participant=846, Epoch=200, NLL=31.7917, omega=0.2590, tau=0.6428, condition=regret_late
# Participant=846, Epoch=300, NLL=31.9292, omega=0.2093, tau=0.6398, condition=regret_late
# Participant=846, Epoch=400, NLL=31.6915, omega=0.1564, tau=0.6411, condition=regret_late
# Participant=846, Epoch=500, NLL=31.7879, omega=0.1236, tau=0.6435, condition=regret_late
# Participant=880, Epoch=1, NLL=48.8920, omega=0.0000, tau=0.4961, condition=control
# Participant=880, Epoch=100, NLL=32.8566, omega=0.0000, tau=0.1993, condition=control
# Participant=880, Epoch=200, NLL=23.3200, omega=0.0000, tau=0.0952, condition=control
# Participant=880, Epoch=300, NLL=23.0443, omega=0.0000, tau=0.0837, condition=control
# Participant=880, Epoch=400, NLL=23.0440, omega=0.0000, tau=0.0834, condition=control
# Participant=880, Epoch=500, NLL=23.0440, omega=0.0000, tau=0.0834, condition=control
# Participant=898, Epoch=1, NLL=64.1176, omega=0.0000, tau=0.5039, condition=control
# Participant=898, Epoch=100, NLL=63.9249, omega=0.0000, tau=0.6632, condition=control
# Participant=898, Epoch=200, NLL=63.9249, omega=0.0000, tau=0.6617, condition=control
# Participant=898, Epoch=300, NLL=63.9248, omega=0.0000, tau=0.6617, condition=control
# Participant=898, Epoch=400, NLL=63.9248, omega=0.0000, tau=0.6617, condition=control
# Participant=898, Epoch=500, NLL=63.9248, omega=0.0000, tau=0.6617, condition=control
# Participant=941, Epoch=1, NLL=54.2704, omega=0.0000, tau=0.4961, condition=control
# Participant=941, Epoch=100, NLL=45.1255, omega=0.0000, tau=0.2042, condition=control
# Participant=941, Epoch=200, NLL=41.0574, omega=0.0000, tau=0.1090, condition=control
# Participant=941, Epoch=300, NLL=41.0229, omega=0.0000, tau=0.1034, condition=control
# Participant=941, Epoch=400, NLL=41.0229, omega=0.0000, tau=0.1034, condition=control
# Participant=941, Epoch=500, NLL=41.0229, omega=0.0000, tau=0.1034, condition=control
# Participant=942, Epoch=1, NLL=55.4407, omega=0.0000, tau=0.4961, condition=control
# Participant=942, Epoch=100, NLL=44.8959, omega=0.0000, tau=0.1969, condition=control
# Participant=942, Epoch=200, NLL=38.2609, omega=0.0000, tau=0.0938, condition=control
# Participant=942, Epoch=300, NLL=38.2316, omega=0.0000, tau=0.0901, condition=control
# Participant=942, Epoch=400, NLL=38.2316, omega=0.0000, tau=0.0901, condition=control
# Participant=942, Epoch=500, NLL=38.2316, omega=0.0000, tau=0.0901, condition=control
# Participant=924, Epoch=1, NLL=56.4465, omega=0.0000, tau=0.4961, condition=control
# Participant=924, Epoch=100, NLL=54.8428, omega=0.0000, tau=0.2965, condition=control
# Participant=924, Epoch=200, NLL=54.8424, omega=0.0000, tau=0.2985, condition=control
# Participant=924, Epoch=300, NLL=54.8424, omega=0.0000, tau=0.2986, condition=control
# Participant=924, Epoch=400, NLL=54.8424, omega=0.0000, tau=0.2986, condition=control
# Participant=924, Epoch=500, NLL=54.8424, omega=0.0000, tau=0.2986, condition=control
# Participant=940, Epoch=1, NLL=52.5315, omega=0.0000, tau=0.4961, condition=control
# Participant=940, Epoch=100, NLL=48.6038, omega=0.0000, tau=0.2552, condition=control
# Participant=940, Epoch=200, NLL=48.5905, omega=0.0000, tau=0.2479, condition=control
# Participant=940, Epoch=300, NLL=48.5905, omega=0.0000, tau=0.2478, condition=control
# Participant=940, Epoch=400, NLL=48.5905, omega=0.0000, tau=0.2478, condition=control
# Participant=940, Epoch=500, NLL=48.5905, omega=0.0000, tau=0.2478, condition=control
# Participant=906, Epoch=1, NLL=57.7326, omega=0.0000, tau=0.4961, condition=control
# Participant=906, Epoch=100, NLL=55.4735, omega=0.0000, tau=0.2599, condition=control
# Participant=906, Epoch=200, NLL=55.4706, omega=0.0000, tau=0.2557, condition=control
# Participant=906, Epoch=300, NLL=55.4706, omega=0.0000, tau=0.2556, condition=control
# Participant=906, Epoch=400, NLL=55.4706, omega=0.0000, tau=0.2556, condition=control
# Participant=906, Epoch=500, NLL=55.4706, omega=0.0000, tau=0.2556, condition=control
# Participant=912, Epoch=1, NLL=43.5706, omega=0.0000, tau=0.4961, condition=control
# Participant=912, Epoch=100, NLL=30.7451, omega=0.0000, tau=0.2170, condition=control
# Participant=912, Epoch=200, NLL=28.6422, omega=0.0000, tau=0.1535, condition=control
# Participant=912, Epoch=300, NLL=28.6413, omega=0.0000, tau=0.1525, condition=control
# Participant=912, Epoch=400, NLL=28.6413, omega=0.0000, tau=0.1525, condition=control
# Participant=912, Epoch=500, NLL=28.6413, omega=0.0000, tau=0.1525, condition=control
# Participant=916, Epoch=1, NLL=49.9113, omega=0.0000, tau=0.4961, condition=control
# Participant=916, Epoch=100, NLL=34.0978, omega=0.0000, tau=0.1970, condition=control
# Participant=916, Epoch=200, NLL=19.5784, omega=0.0000, tau=0.0786, condition=control
# Participant=916, Epoch=300, NLL=17.7506, omega=0.0000, tau=0.0555, condition=control
# Participant=916, Epoch=400, NLL=17.7001, omega=0.0000, tau=0.0522, condition=control
# Participant=916, Epoch=500, NLL=17.6996, omega=0.0000, tau=0.0519, condition=control
# Participant=939, Epoch=1, NLL=62.9732, omega=0.0000, tau=0.4961, condition=control
# Participant=939, Epoch=100, NLL=62.9320, omega=0.0000, tau=0.4396, condition=control
# Participant=939, Epoch=200, NLL=62.9320, omega=0.0000, tau=0.4394, condition=control
# Participant=939, Epoch=300, NLL=62.9320, omega=0.0000, tau=0.4394, condition=control
# Participant=939, Epoch=400, NLL=62.9320, omega=0.0000, tau=0.4394, condition=control
# Participant=939, Epoch=500, NLL=62.9320, omega=0.0000, tau=0.4394, condition=control
# Participant=900, Epoch=1, NLL=63.9161, omega=0.0000, tau=0.4961, condition=control
# Participant=900, Epoch=100, NLL=63.8305, omega=0.0000, tau=0.3965, condition=control
# Participant=900, Epoch=200, NLL=63.8305, omega=0.0000, tau=0.3966, condition=control
# Participant=900, Epoch=300, NLL=63.8305, omega=0.0000, tau=0.3966, condition=control
# Participant=900, Epoch=400, NLL=63.8305, omega=0.0000, tau=0.3966, condition=control
# Participant=900, Epoch=500, NLL=63.8305, omega=0.0000, tau=0.3966, condition=control
# Participant=894, Epoch=1, NLL=63.5107, omega=0.0000, tau=0.4961, condition=control
# Participant=894, Epoch=100, NLL=63.2470, omega=0.0000, tau=0.3427, condition=control
# Participant=894, Epoch=200, NLL=63.2470, omega=0.0000, tau=0.3428, condition=control
# Participant=894, Epoch=300, NLL=63.2470, omega=0.0000, tau=0.3428, condition=control
# Participant=894, Epoch=400, NLL=63.2470, omega=0.0000, tau=0.3428, condition=control
# Participant=894, Epoch=500, NLL=63.2470, omega=0.0000, tau=0.3428, condition=control
# Participant=935, Epoch=1, NLL=60.4359, omega=0.0000, tau=0.5039, condition=control
# Participant=935, Epoch=100, NLL=60.2767, omega=0.0000, tau=0.5851, condition=control
# Participant=935, Epoch=200, NLL=60.2767, omega=0.0000, tau=0.5847, condition=control
# Participant=935, Epoch=300, NLL=60.2767, omega=0.0000, tau=0.5847, condition=control
# Participant=935, Epoch=400, NLL=60.2767, omega=0.0000, tau=0.5847, condition=control
# Participant=935, Epoch=500, NLL=60.2767, omega=0.0000, tau=0.5847, condition=control
# Participant=918, Epoch=1, NLL=43.8889, omega=0.0000, tau=0.4961, condition=control
# Participant=918, Epoch=100, NLL=22.5084, omega=0.0000, tau=0.1984, condition=control
# Participant=918, Epoch=200, NLL=7.2571, omega=0.0000, tau=0.0876, condition=control
# Participant=918, Epoch=300, NLL=5.4103, omega=0.0000, tau=0.0636, condition=control
# Participant=918, Epoch=400, NLL=5.1696, omega=0.0000, tau=0.0559, condition=control
# Participant=918, Epoch=500, NLL=5.1300, omega=0.0000, tau=0.0528, condition=control
# Participant=910, Epoch=1, NLL=55.0439, omega=0.0000, tau=0.4961, condition=control
# Participant=910, Epoch=100, NLL=48.4867, omega=0.0000, tau=0.2178, condition=control
# Participant=910, Epoch=200, NLL=47.9611, omega=0.0000, tau=0.1789, condition=control
# Participant=910, Epoch=300, NLL=47.9611, omega=0.0000, tau=0.1791, condition=control
# Participant=910, Epoch=400, NLL=47.9611, omega=0.0000, tau=0.1791, condition=control
# Participant=910, Epoch=500, NLL=47.9611, omega=0.0000, tau=0.1791, condition=control
# Participant=886, Epoch=1, NLL=61.9147, omega=0.0000, tau=0.4961, condition=control
# Participant=886, Epoch=100, NLL=61.8366, omega=0.0000, tau=0.4283, condition=control
# Participant=886, Epoch=200, NLL=61.8366, omega=0.0000, tau=0.4282, condition=control
# Participant=886, Epoch=300, NLL=61.8366, omega=0.0000, tau=0.4282, condition=control
# Participant=886, Epoch=400, NLL=61.8366, omega=0.0000, tau=0.4282, condition=control
# Participant=886, Epoch=500, NLL=61.8366, omega=0.0000, tau=0.4282, condition=control
# Participant=927, Epoch=1, NLL=50.1042, omega=0.0000, tau=0.4961, condition=control
# Participant=927, Epoch=100, NLL=39.5952, omega=0.0000, tau=0.2122, condition=control
# Participant=927, Epoch=200, NLL=37.7868, omega=0.0000, tau=0.1509, condition=control
# Participant=927, Epoch=300, NLL=37.7868, omega=0.0000, tau=0.1509, condition=control
# Participant=927, Epoch=400, NLL=37.7868, omega=0.0000, tau=0.1509, condition=control
# Participant=927, Epoch=500, NLL=37.7868, omega=0.0000, tau=0.1509, condition=control
# Participant=913, Epoch=1, NLL=50.1989, omega=0.0000, tau=0.4961, condition=control
# Participant=913, Epoch=100, NLL=43.2686, omega=0.0000, tau=0.2317, condition=control
# Participant=913, Epoch=200, NLL=43.0287, omega=0.0000, tau=0.2055, condition=control
# Participant=913, Epoch=300, NLL=43.0287, omega=0.0000, tau=0.2056, condition=control
# Participant=913, Epoch=400, NLL=43.0288, omega=0.0000, tau=0.2056, condition=control
# Participant=913, Epoch=500, NLL=43.0288, omega=0.0000, tau=0.2056, condition=control
# Participant=917, Epoch=1, NLL=46.1719, omega=0.0000, tau=0.4961, condition=control
# Participant=917, Epoch=100, NLL=26.0502, omega=0.0000, tau=0.1963, condition=control
# Participant=917, Epoch=200, NLL=7.0968, omega=0.0000, tau=0.0774, condition=control
# Participant=917, Epoch=300, NLL=3.6092, omega=0.0000, tau=0.0499, condition=control
# Participant=917, Epoch=400, NLL=2.9425, omega=0.0000, tau=0.0403, condition=control
# Participant=917, Epoch=500, NLL=2.7268, omega=0.0000, tau=0.0353, condition=control
# Participant=911, Epoch=1, NLL=52.3847, omega=0.0000, tau=0.4961, condition=control
# Participant=911, Epoch=100, NLL=34.8871, omega=0.0000, tau=0.1894, condition=control
# Participant=911, Epoch=200, NLL=7.1541, omega=0.0000, tau=0.0598, condition=control
# Participant=911, Epoch=300, NLL=2.0887, omega=0.0000, tau=0.0359, condition=control
# Participant=911, Epoch=400, NLL=1.4596, omega=0.0000, tau=0.0293, condition=control
# Participant=911, Epoch=500, NLL=1.2831, omega=0.0000, tau=0.0261, condition=control
# Participant=885, Epoch=1, NLL=42.5075, omega=0.0000, tau=0.4961, condition=control
# Participant=885, Epoch=100, NLL=20.1467, omega=0.0000, tau=0.1989, condition=control
# Participant=885, Epoch=200, NLL=4.6056, omega=0.0000, tau=0.0886, condition=control
# Participant=885, Epoch=300, NLL=2.5426, omega=0.0000, tau=0.0635, condition=control
# Participant=885, Epoch=400, NLL=2.1333, omega=0.0000, tau=0.0538, condition=control
# Participant=885, Epoch=500, NLL=1.9892, omega=0.0000, tau=0.0484, condition=control
# Participant=938, Epoch=1, NLL=51.3015, omega=0.0000, tau=0.4961, condition=control
# Participant=938, Epoch=100, NLL=40.7575, omega=0.0000, tau=0.2096, condition=control
# Participant=938, Epoch=200, NLL=38.6584, omega=0.0000, tau=0.1443, condition=control
# Participant=938, Epoch=300, NLL=38.6584, omega=0.0000, tau=0.1442, condition=control
# Participant=938, Epoch=400, NLL=38.6584, omega=0.0000, tau=0.1442, condition=control
# Participant=938, Epoch=500, NLL=38.6584, omega=0.0000, tau=0.1442, condition=control
# Participant=931, Epoch=1, NLL=61.1417, omega=0.0000, tau=0.4961, condition=control
# Participant=931, Epoch=100, NLL=60.8154, omega=0.0000, tau=0.3722, condition=control
# Participant=931, Epoch=200, NLL=60.8154, omega=0.0000, tau=0.3714, condition=control
# Participant=931, Epoch=300, NLL=60.8154, omega=0.0000, tau=0.3714, condition=control
# Participant=931, Epoch=400, NLL=60.8154, omega=0.0000, tau=0.3714, condition=control
# Participant=931, Epoch=500, NLL=60.8154, omega=0.0000, tau=0.3714, condition=control
# Participant=926, Epoch=1, NLL=49.1459, omega=0.0000, tau=0.4961, condition=control
# Participant=926, Epoch=100, NLL=30.7915, omega=0.0000, tau=0.1943, condition=control
# Participant=926, Epoch=200, NLL=11.0921, omega=0.0000, tau=0.0725, condition=control
# Participant=926, Epoch=300, NLL=7.7314, omega=0.0000, tau=0.0468, condition=control
# Participant=926, Epoch=400, NLL=7.4499, omega=0.0000, tau=0.0407, condition=control
# Participant=926, Epoch=500, NLL=7.4302, omega=0.0000, tau=0.0391, condition=control
# Participant=923, Epoch=1, NLL=46.2150, omega=0.0000, tau=0.4961, condition=control
# Participant=923, Epoch=100, NLL=32.8491, omega=0.0000, tau=0.2111, condition=control
# Participant=923, Epoch=200, NLL=29.5923, omega=0.0000, tau=0.1352, condition=control
# Participant=923, Epoch=300, NLL=29.5835, omega=0.0000, tau=0.1322, condition=control
# Participant=923, Epoch=400, NLL=29.5835, omega=0.0000, tau=0.1322, condition=control
# Participant=923, Epoch=500, NLL=29.5835, omega=0.0000, tau=0.1322, condition=control
# Participant=932, Epoch=1, NLL=51.3809, omega=0.0000, tau=0.4961, condition=control
# Participant=932, Epoch=100, NLL=38.6296, omega=0.0000, tau=0.2016, condition=control
# Participant=932, Epoch=200, NLL=32.9557, omega=0.0000, tau=0.1083, condition=control
# Participant=932, Epoch=300, NLL=32.9290, omega=0.0000, tau=0.1042, condition=control
# Participant=932, Epoch=400, NLL=32.9290, omega=0.0000, tau=0.1042, condition=control
# Participant=932, Epoch=500, NLL=32.9290, omega=0.0000, tau=0.1042, condition=control
# Participant=899, Epoch=1, NLL=52.3269, omega=0.0000, tau=0.4961, condition=control
# Participant=899, Epoch=100, NLL=39.7308, omega=0.0000, tau=0.1992, condition=control
# Participant=899, Epoch=200, NLL=31.9064, omega=0.0000, tau=0.0940, condition=control
# Participant=899, Epoch=300, NLL=31.7743, omega=0.0000, tau=0.0859, condition=control
# Participant=899, Epoch=400, NLL=31.7743, omega=0.0000, tau=0.0859, condition=control
# Participant=899, Epoch=500, NLL=31.7743, omega=0.0000, tau=0.0859, condition=control
# Participant=905, Epoch=1, NLL=51.2387, omega=0.0000, tau=0.4961, condition=control
# Participant=905, Epoch=100, NLL=41.8949, omega=0.0000, tau=0.2120, condition=control
# Participant=905, Epoch=200, NLL=39.7776, omega=0.0000, tau=0.1398, condition=control
# Participant=905, Epoch=300, NLL=39.7766, omega=0.0000, tau=0.1388, condition=control
# Participant=905, Epoch=400, NLL=39.7766, omega=0.0000, tau=0.1388, condition=control
# Participant=905, Epoch=500, NLL=39.7766, omega=0.0000, tau=0.1388, condition=control
# Participant=897, Epoch=1, NLL=62.7863, omega=0.0000, tau=0.5039, condition=control
# Participant=897, Epoch=100, NLL=62.5625, omega=0.0000, tau=0.6372, condition=control
# Participant=897, Epoch=200, NLL=62.5625, omega=0.0000, tau=0.6372, condition=control
# Participant=897, Epoch=300, NLL=62.5625, omega=0.0000, tau=0.6372, condition=control
# Participant=897, Epoch=400, NLL=62.5625, omega=0.0000, tau=0.6372, condition=control
# Participant=897, Epoch=500, NLL=62.5625, omega=0.0000, tau=0.6372, condition=control
# Participant=888, Epoch=1, NLL=46.6383, omega=0.0000, tau=0.4961, condition=control
# Participant=888, Epoch=100, NLL=25.4152, omega=0.0000, tau=0.1943, condition=control
# Participant=888, Epoch=200, NLL=5.0352, omega=0.0000, tau=0.0761, condition=control
# Participant=888, Epoch=300, NLL=2.0935, omega=0.0000, tau=0.0514, condition=control
# Participant=888, Epoch=400, NLL=1.5630, omega=0.0000, tau=0.0427, condition=control
# Participant=888, Epoch=500, NLL=1.3782, omega=0.0000, tau=0.0379, condition=control
# Participant=920, Epoch=1, NLL=62.4743, omega=0.0000, tau=0.4961, condition=control
# Participant=920, Epoch=100, NLL=61.9643, omega=0.0000, tau=0.3117, condition=control
# Participant=920, Epoch=200, NLL=61.9641, omega=0.0000, tau=0.3138, condition=control
# Participant=920, Epoch=300, NLL=61.9641, omega=0.0000, tau=0.3138, condition=control
# Participant=920, Epoch=400, NLL=61.9641, omega=0.0000, tau=0.3138, condition=control
# Participant=920, Epoch=500, NLL=61.9641, omega=0.0000, tau=0.3138, condition=control
# Participant=903, Epoch=1, NLL=55.9271, omega=0.0000, tau=0.4961, condition=control
# Participant=903, Epoch=100, NLL=52.7711, omega=0.0000, tau=0.2514, condition=control
# Participant=903, Epoch=200, NLL=52.7582, omega=0.0000, tau=0.2434, condition=control
# Participant=903, Epoch=300, NLL=52.7582, omega=0.0000, tau=0.2433, condition=control
# Participant=903, Epoch=400, NLL=52.7582, omega=0.0000, tau=0.2433, condition=control
# Participant=903, Epoch=500, NLL=52.7582, omega=0.0000, tau=0.2433, condition=control
# Participant=915, Epoch=1, NLL=40.6229, omega=0.0000, tau=0.4961, condition=control
# Participant=915, Epoch=100, NLL=18.8317, omega=0.0000, tau=0.2023, condition=control
# Participant=915, Epoch=200, NLL=7.0477, omega=0.0000, tau=0.0992, condition=control
# Participant=915, Epoch=300, NLL=6.0892, omega=0.0000, tau=0.0788, condition=control
# Participant=915, Epoch=400, NLL=6.0267, omega=0.0000, tau=0.0738, condition=control
# Participant=915, Epoch=500, NLL=6.0231, omega=0.0000, tau=0.0726, condition=control
# Participant=934, Epoch=1, NLL=58.6182, omega=0.0000, tau=0.4961, condition=control
# Participant=934, Epoch=100, NLL=57.3583, omega=0.0000, tau=0.2960, condition=control
# Participant=934, Epoch=200, NLL=57.3579, omega=0.0000, tau=0.2982, condition=control
# Participant=934, Epoch=300, NLL=57.3579, omega=0.0000, tau=0.2982, condition=control
# Participant=934, Epoch=400, NLL=57.3579, omega=0.0000, tau=0.2982, condition=control
# Participant=934, Epoch=500, NLL=57.3579, omega=0.0000, tau=0.2982, condition=control
# Participant=893, Epoch=1, NLL=63.8595, omega=0.0000, tau=0.4961, condition=control
# Participant=893, Epoch=100, NLL=63.7612, omega=0.0000, tau=0.3912, condition=control
# Participant=893, Epoch=200, NLL=63.7612, omega=0.0000, tau=0.3911, condition=control
# Participant=893, Epoch=300, NLL=63.7612, omega=0.0000, tau=0.3911, condition=control
# Participant=893, Epoch=400, NLL=63.7612, omega=0.0000, tau=0.3911, condition=control
# Participant=893, Epoch=500, NLL=63.7612, omega=0.0000, tau=0.3911, condition=control
# Participant=929, Epoch=1, NLL=48.5854, omega=0.0000, tau=0.4961, condition=control
# Participant=929, Epoch=100, NLL=36.6142, omega=0.0000, tau=0.2099, condition=control
# Participant=929, Epoch=200, NLL=33.6933, omega=0.0000, tau=0.1357, condition=control
# Participant=929, Epoch=300, NLL=33.6913, omega=0.0000, tau=0.1344, condition=control
# Participant=929, Epoch=400, NLL=33.6913, omega=0.0000, tau=0.1344, condition=control
# Participant=929, Epoch=500, NLL=33.6913, omega=0.0000, tau=0.1344, condition=control
# Participant=881, Epoch=1, NLL=55.8628, omega=0.0000, tau=0.4961, condition=control
# Participant=881, Epoch=100, NLL=41.9483, omega=0.0000, tau=0.1874, condition=control
# Participant=881, Epoch=200, NLL=13.2647, omega=0.0000, tau=0.0526, condition=control
# Participant=881, Epoch=300, NLL=5.6761, omega=0.0000, tau=0.0273, condition=control
# Participant=881, Epoch=400, NLL=4.4158, omega=0.0000, tau=0.0203, condition=control
# Participant=881, Epoch=500, NLL=3.9674, omega=0.0000, tau=0.0168, condition=control
# ...
# Participant=866, Epoch=200, NLL=30.0071, omega=0.2949, tau=0.3258, condition=regret_early
# Participant=866, Epoch=300, NLL=29.9088, omega=0.2594, tau=0.3145, condition=regret_early
# Participant=866, Epoch=400, NLL=30.7784, omega=0.2425, tau=0.3177, condition=regret_early
# Participant=866, Epoch=500, NLL=29.9509, omega=0.2277, tau=0.3262, condition=regret_early
# Participant=855, Epoch=1, NLL=32.6794, omega=0.4961, tau=0.5039, condition=regret_early
# Participant=855, Epoch=100, NLL=32.0825, omega=0.2540, tau=0.3561, condition=regret_early
# Participant=855, Epoch=200, NLL=32.1598, omega=0.1504, tau=0.3267, condition=regret_early
# Participant=855, Epoch=300, NLL=32.0238, omega=0.1088, tau=0.3149, condition=regret_early
# Participant=855, Epoch=400, NLL=32.0412, omega=0.0804, tau=0.3178, condition=regret_early
# Participant=855, Epoch=500, NLL=31.9079, omega=0.0654, tau=0.3134, condition=regret_early
# Participant=876, Epoch=1, NLL=29.9925, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=876, Epoch=100, NLL=28.5587, omega=0.2599, tau=0.3190, condition=regret_early
# Participant=876, Epoch=200, NLL=28.5087, omega=0.1622, tau=0.3170, condition=regret_early
# Participant=876, Epoch=300, NLL=28.5435, omega=0.1069, tau=0.3153, condition=regret_early
# Participant=876, Epoch=400, NLL=28.3078, omega=0.0804, tau=0.3072, condition=regret_early
# Participant=876, Epoch=500, NLL=28.2495, omega=0.0656, tau=0.3158, condition=regret_early
# Participant=754, Epoch=1, NLL=27.0408, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=754, Epoch=100, NLL=21.0695, omega=0.2334, tau=0.2061, condition=regret_early
# Participant=754, Epoch=200, NLL=21.5502, omega=0.1262, tau=0.1385, condition=regret_early
# Participant=754, Epoch=300, NLL=20.8631, omega=0.0866, tau=0.1340, condition=regret_early
# Participant=754, Epoch=400, NLL=20.9715, omega=0.0662, tau=0.1364, condition=regret_early
# Participant=754, Epoch=500, NLL=19.8820, omega=0.0540, tau=0.1359, condition=regret_early
# Participant=755, Epoch=1, NLL=31.6592, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=755, Epoch=100, NLL=28.3703, omega=0.2954, tau=0.2949, condition=regret_early
# Participant=755, Epoch=200, NLL=23.0518, omega=0.1668, tau=0.1410, condition=regret_early
# Participant=755, Epoch=300, NLL=24.7618, omega=0.0957, tau=0.0982, condition=regret_early
# Participant=755, Epoch=400, NLL=27.4872, omega=0.0765, tau=0.0798, condition=regret_early
# Participant=755, Epoch=500, NLL=29.3712, omega=0.0737, tau=0.0750, condition=regret_early
# Participant=850, Epoch=1, NLL=29.7237, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=850, Epoch=100, NLL=26.6106, omega=0.2630, tau=0.2190, condition=regret_early
# Participant=850, Epoch=200, NLL=26.4663, omega=0.1202, tau=0.1120, condition=regret_early
# Participant=850, Epoch=300, NLL=24.8999, omega=0.0721, tau=0.1004, condition=regret_early
# Participant=850, Epoch=400, NLL=25.4062, omega=0.0484, tau=0.0981, condition=regret_early
# Participant=850, Epoch=500, NLL=25.3974, omega=0.0355, tau=0.0971, condition=regret_early
# Participant=828, Epoch=1, NLL=33.4887, omega=0.5039, tau=0.5039, condition=regret_early
# Participant=828, Epoch=100, NLL=33.7588, omega=0.4170, tau=0.8251, condition=regret_early
# Participant=828, Epoch=200, NLL=33.7222, omega=0.3427, tau=1.0737, condition=regret_early
# Participant=828, Epoch=300, NLL=32.7896, omega=0.3038, tau=1.2752, condition=regret_early
# Participant=828, Epoch=400, NLL=33.2093, omega=0.2696, tau=1.4501, condition=regret_early
# Participant=828, Epoch=500, NLL=33.2754, omega=0.2491, tau=1.5981, condition=regret_early
# Participant=820, Epoch=1, NLL=23.5995, omega=0.5039, tau=0.4961, condition=regret_early
# Participant=820, Epoch=100, NLL=20.3084, omega=0.3989, tau=0.2054, condition=regret_early
# Participant=820, Epoch=200, NLL=13.9885, omega=0.1898, tau=0.1020, condition=regret_early
# Participant=820, Epoch=300, NLL=13.9131, omega=0.1250, tau=0.0887, condition=regret_early
# Participant=820, Epoch=400, NLL=13.0895, omega=0.0962, tau=0.0886, condition=regret_early
# Participant=820, Epoch=500, NLL=13.4149, omega=0.0786, tau=0.0883, condition=regret_early
# Participant=818, Epoch=1, NLL=32.7746, omega=0.4961, tau=0.5039, condition=regret_early
# Participant=818, Epoch=100, NLL=32.1470, omega=0.2676, tau=0.2950, condition=regret_early
# Participant=818, Epoch=200, NLL=31.9098, omega=0.1380, tau=0.1795, condition=regret_early
# Participant=818, Epoch=300, NLL=30.6860, omega=0.0809, tau=0.1724, condition=regret_early
# Participant=818, Epoch=400, NLL=30.8022, omega=0.0587, tau=0.1684, condition=regret_early
# Participant=818, Epoch=500, NLL=30.2670, omega=0.0437, tau=0.1649, condition=regret_early
# Participant=787, Epoch=1, NLL=26.5409, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=787, Epoch=100, NLL=23.2971, omega=0.3494, tau=0.2246, condition=regret_early
# Participant=787, Epoch=200, NLL=10.5170, omega=0.1917, tau=0.0750, condition=regret_early
# Participant=787, Epoch=300, NLL=1.7031, omega=0.1006, tau=0.0372, condition=regret_early
# Participant=787, Epoch=400, NLL=1.1822, omega=0.0786, tau=0.0281, condition=regret_early
# Participant=787, Epoch=500, NLL=1.3366, omega=0.0689, tau=0.0242, condition=regret_early
# Participant=843, Epoch=1, NLL=32.2844, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=843, Epoch=100, NLL=32.1805, omega=0.2947, tau=0.6644, condition=regret_early
# Participant=843, Epoch=200, NLL=32.1035, omega=0.2155, tau=0.6400, condition=regret_early
# Participant=843, Epoch=300, NLL=32.4382, omega=0.1568, tau=0.6276, condition=regret_early
# Participant=843, Epoch=400, NLL=32.2511, omega=0.1265, tau=0.6197, condition=regret_early
# Participant=843, Epoch=500, NLL=32.3435, omega=0.1079, tau=0.6119, condition=regret_early
# Participant=848, Epoch=1, NLL=27.8643, omega=0.5039, tau=0.4961, condition=regret_early
# Participant=848, Epoch=100, NLL=25.1658, omega=0.3035, tau=0.2120, condition=regret_early
# Participant=848, Epoch=200, NLL=25.2269, omega=0.1793, tau=0.1581, condition=regret_early
# Participant=848, Epoch=300, NLL=25.0798, omega=0.1269, tau=0.1591, condition=regret_early
# Participant=848, Epoch=400, NLL=24.7720, omega=0.1003, tau=0.1557, condition=regret_early
# Participant=848, Epoch=500, NLL=24.8381, omega=0.0854, tau=0.1578, condition=regret_early
# Participant=805, Epoch=1, NLL=32.7621, omega=0.4961, tau=0.5039, condition=regret_early
# Participant=805, Epoch=100, NLL=32.7633, omega=0.2760, tau=0.7453, condition=regret_early
# Participant=805, Epoch=200, NLL=32.5423, omega=0.1851, tau=0.8128, condition=regret_early
# Participant=805, Epoch=300, NLL=32.5112, omega=0.1357, tau=0.8093, condition=regret_early
# Participant=805, Epoch=400, NLL=32.5922, omega=0.0992, tau=0.7902, condition=regret_early
# Participant=805, Epoch=500, NLL=32.5691, omega=0.0783, tau=0.7596, condition=regret_early
# Participant=874, Epoch=1, NLL=31.3501, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=874, Epoch=100, NLL=30.9981, omega=0.2757, tau=0.3061, condition=regret_early
# Participant=874, Epoch=200, NLL=30.1423, omega=0.1431, tau=0.1633, condition=regret_early
# Participant=874, Epoch=300, NLL=30.7314, omega=0.0946, tau=0.1475, condition=regret_early
# Participant=874, Epoch=400, NLL=29.9895, omega=0.0643, tau=0.1468, condition=regret_early
# Participant=874, Epoch=500, NLL=30.1123, omega=0.0529, tau=0.1448, condition=regret_early
# Participant=765, Epoch=1, NLL=32.6515, omega=0.4961, tau=0.5039, condition=regret_early
# Participant=765, Epoch=100, NLL=27.7419, omega=0.4212, tau=0.2331, condition=regret_early
# Participant=765, Epoch=200, NLL=28.7454, omega=0.2613, tau=0.1695, condition=regret_early
# Participant=765, Epoch=300, NLL=29.7079, omega=0.1694, tau=0.1694, condition=regret_early
# Participant=765, Epoch=400, NLL=28.7350, omega=0.1266, tau=0.1580, condition=regret_early
# Participant=765, Epoch=500, NLL=28.7717, omega=0.1053, tau=0.1531, condition=regret_early
# Participant=789, Epoch=1, NLL=31.3853, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=789, Epoch=100, NLL=30.2035, omega=0.2925, tau=0.2694, condition=regret_early
# Participant=789, Epoch=200, NLL=29.7971, omega=0.1573, tau=0.1903, condition=regret_early
# Participant=789, Epoch=300, NLL=30.4490, omega=0.1121, tau=0.1753, condition=regret_early
# Participant=789, Epoch=400, NLL=30.4965, omega=0.0824, tau=0.1735, condition=regret_early
# Participant=789, Epoch=500, NLL=30.4125, omega=0.0674, tau=0.1715, condition=regret_early
# Participant=826, Epoch=1, NLL=31.8278, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=826, Epoch=100, NLL=30.5337, omega=0.3053, tau=0.3205, condition=regret_early
# Participant=826, Epoch=200, NLL=30.6747, omega=0.1916, tau=0.2770, condition=regret_early
# Participant=826, Epoch=300, NLL=30.4519, omega=0.1345, tau=0.2809, condition=regret_early
# Participant=826, Epoch=400, NLL=30.3232, omega=0.1027, tau=0.2737, condition=regret_early
# Participant=826, Epoch=500, NLL=30.8939, omega=0.0828, tau=0.2750, condition=regret_early
# Participant=757, Epoch=1, NLL=27.8667, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=757, Epoch=100, NLL=26.4219, omega=0.2652, tau=0.2468, condition=regret_early
# Participant=757, Epoch=200, NLL=26.8759, omega=0.1610, tau=0.2346, condition=regret_early
# Participant=757, Epoch=300, NLL=26.5778, omega=0.1121, tau=0.2371, condition=regret_early
# Participant=757, Epoch=400, NLL=26.3033, omega=0.0863, tau=0.2449, condition=regret_early
# Participant=757, Epoch=500, NLL=26.5810, omega=0.0714, tau=0.2428, condition=regret_early
# Participant=701, Epoch=1, NLL=31.6989, omega=0.4961, tau=0.5039, condition=regret_early
# Participant=701, Epoch=100, NLL=32.1477, omega=0.2545, tau=0.5445, condition=regret_early
# Participant=701, Epoch=200, NLL=31.4252, omega=0.1423, tau=0.5166, condition=regret_early
# Participant=701, Epoch=300, NLL=31.3633, omega=0.0906, tau=0.5108, condition=regret_early
# Participant=701, Epoch=400, NLL=31.4122, omega=0.0638, tau=0.5134, condition=regret_early
# Participant=701, Epoch=500, NLL=31.5720, omega=0.0458, tau=0.5094, condition=regret_early
# Participant=737, Epoch=1, NLL=31.1510, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=737, Epoch=100, NLL=26.7666, omega=0.2564, tau=0.2459, condition=regret_early
# Participant=737, Epoch=200, NLL=27.8789, omega=0.1556, tau=0.2268, condition=regret_early
# Participant=737, Epoch=300, NLL=27.8277, omega=0.1058, tau=0.2270, condition=regret_early
# Participant=737, Epoch=400, NLL=27.8697, omega=0.0775, tau=0.2294, condition=regret_early
# Participant=737, Epoch=500, NLL=27.3225, omega=0.0610, tau=0.2286, condition=regret_early
# Participant=719, Epoch=1, NLL=28.9169, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=719, Epoch=100, NLL=26.8853, omega=0.2473, tau=0.2150, condition=regret_early
# Participant=719, Epoch=200, NLL=25.4430, omega=0.1374, tau=0.1824, condition=regret_early
# Participant=719, Epoch=300, NLL=25.1263, omega=0.0873, tau=0.1760, condition=regret_early
# Participant=719, Epoch=400, NLL=25.1290, omega=0.0681, tau=0.1754, condition=regret_early
# Participant=719, Epoch=500, NLL=25.2729, omega=0.0570, tau=0.1770, condition=regret_early
# Participant=728, Epoch=1, NLL=28.0551, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=728, Epoch=100, NLL=26.1347, omega=0.2692, tau=0.2821, condition=regret_early
# Participant=728, Epoch=200, NLL=26.2609, omega=0.1832, tau=0.2757, condition=regret_early
# Participant=728, Epoch=300, NLL=26.2187, omega=0.1398, tau=0.2743, condition=regret_early
# Participant=728, Epoch=400, NLL=26.2338, omega=0.1048, tau=0.2779, condition=regret_early
# Participant=728, Epoch=500, NLL=26.0848, omega=0.0898, tau=0.2803, condition=regret_early
# Participant=713, Epoch=1, NLL=31.7871, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=713, Epoch=100, NLL=30.8172, omega=0.2518, tau=0.2274, condition=regret_early
# Participant=713, Epoch=200, NLL=29.3562, omega=0.1260, tau=0.1516, condition=regret_early
# Participant=713, Epoch=300, NLL=30.2914, omega=0.0807, tau=0.1553, condition=regret_early
# Participant=713, Epoch=400, NLL=30.0688, omega=0.0579, tau=0.1489, condition=regret_early
# Participant=713, Epoch=500, NLL=29.5858, omega=0.0457, tau=0.1490, condition=regret_early
# Participant=710, Epoch=1, NLL=23.8213, omega=0.4961, tau=0.4961, condition=regret_early
# Participant=710, Epoch=100, NLL=16.7110, omega=0.2918, tau=0.2006, condition=regret_early
# Participant=710, Epoch=200, NLL=7.4222, omega=0.1531, tau=0.0721, condition=regret_early
# Participant=710, Epoch=300, NLL=6.9209, omega=0.1064, tau=0.0464, condition=regret_early
# Participant=710, Epoch=400, NLL=5.4795, omega=0.0855, tau=0.0398, condition=regret_early
# Participant=710, Epoch=500, NLL=5.3285, omega=0.0683, tau=0.0375, condition=regret_early
# Participant=716, Epoch=1, NLL=31.9320, omega=0.4961, tau=0.5039, condition=regret_early
# Participant=716, Epoch=100, NLL=32.1163, omega=0.2655, tau=0.5248, condition=regret_early
# Participant=716, Epoch=200, NLL=32.1511, omega=0.1778, tau=0.4982, condition=regret_early
# Participant=716, Epoch=300, NLL=31.8894, omega=0.1249, tau=0.4878, condition=regret_early
# Participant=716, Epoch=400, NLL=31.8574, omega=0.0930, tau=0.4855, condition=regret_early
# Participant=716, Epoch=500, NLL=31.8342, omega=0.0711, tau=0.4846, condition=regret_early
# Participant=738, Epoch=1, NLL=28.7944, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=738, Epoch=100, NLL=27.4361, omega=0.2474, tau=0.2811, condition=regret_late
# Participant=738, Epoch=200, NLL=27.4000, omega=0.1418, tau=0.2649, condition=regret_late
# Participant=738, Epoch=300, NLL=27.3811, omega=0.0947, tau=0.2621, condition=regret_late
# Participant=738, Epoch=400, NLL=27.3137, omega=0.0717, tau=0.2630, condition=regret_late
# Participant=738, Epoch=500, NLL=27.1501, omega=0.0533, tau=0.2600, condition=regret_late
# Participant=711, Epoch=1, NLL=25.4551, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=711, Epoch=100, NLL=18.1542, omega=0.3177, tau=0.2136, condition=regret_late
# Participant=711, Epoch=200, NLL=16.4270, omega=0.1885, tau=0.1524, condition=regret_late
# Participant=711, Epoch=300, NLL=16.5659, omega=0.1321, tau=0.1524, condition=regret_late
# Participant=711, Epoch=400, NLL=16.1799, omega=0.1042, tau=0.1512, condition=regret_late
# Participant=711, Epoch=500, NLL=16.1142, omega=0.0805, tau=0.1508, condition=regret_late
# Participant=717, Epoch=1, NLL=22.2752, omega=0.5039, tau=0.4961, condition=regret_late
# Participant=717, Epoch=100, NLL=15.2073, omega=0.3148, tau=0.2018, condition=regret_late
# Participant=717, Epoch=200, NLL=7.1352, omega=0.1724, tau=0.0843, condition=regret_late
# Participant=717, Epoch=300, NLL=7.4007, omega=0.1146, tau=0.0666, condition=regret_late
# Participant=717, Epoch=400, NLL=6.9758, omega=0.0841, tau=0.0646, condition=regret_late
# Participant=717, Epoch=500, NLL=6.5054, omega=0.0686, tau=0.0651, condition=regret_late
# Participant=744, Epoch=1, NLL=24.9844, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=744, Epoch=100, NLL=9.6352, omega=0.3488, tau=0.2039, condition=regret_late
# Participant=744, Epoch=200, NLL=3.3659, omega=0.1982, tau=0.0836, condition=regret_late
# Participant=744, Epoch=300, NLL=5.2791, omega=0.1348, tau=0.0527, condition=regret_late
# Participant=744, Epoch=400, NLL=2.8710, omega=0.1045, tau=0.0417, condition=regret_late
# Participant=744, Epoch=500, NLL=2.3128, omega=0.0815, tau=0.0355, condition=regret_late
# Participant=714, Epoch=1, NLL=27.9572, omega=0.4961, tau=0.4961, condition=regret_late
# Participant=714, Epoch=100, NLL=20.0316, omega=0.2578, tau=0.2010, condition=regret_late
# Participant=714, Epoch=200, NLL=15.8066, omega=0.1344, tau=0.0849, condition=regret_late
# Participant=714, Epoch=300, NLL=15.0025, omega=0.0889, tau=0.0700, condition=regret_late
# Participant=714, Epoch=400, NLL=14.4180, omega=0.0648, tau=0.0699, condition=regret_late
# Participant=714, Epoch=500, NLL=13.8994, omega=0.0548, tau=0.0701, condition=regret_late
# Training complete. Fitted parameters saved to fitted_parameters.csv

# %%
results_df = pd.DataFrame(all_results)
results_df.to_csv('cf_1_sim.csv', index=False)

# %%
print(results_df.groupby("condition")["omega"].describe())
# Out:
#               count      mean       std       min       25%       50%  \
# condition
# control        56.0  0.000000  0.000000  0.000000  0.000000  0.000000
# regret_early   60.0  0.084729  0.047341  0.035466  0.060720  0.072450
# regret_late    60.0  0.114172  0.115842  0.031945  0.055109  0.082259
#
#                    75%       max
# condition
# control       0.000000  0.000000
# regret_early  0.086465  0.254171
# regret_late   0.122989  0.717421

# %%
print(results_df.groupby("condition")["tau"].describe())
# Out:
#               count      mean       std       min       25%       50%  \
# condition
# control        56.0  0.250853  0.236838  0.016771  0.089015  0.164758
# regret_early   60.0  0.279176  0.299500  0.024239  0.137052  0.180928
# regret_late    60.0  0.327517  0.434469  0.026520  0.069338  0.138669
#
#                    75%       max
# condition
# control       0.321055  1.255719
# regret_early  0.295445  1.598133
# regret_late   0.320952  1.731511

# %% [markdown]
# # Generating trial data from the model

# %%
participants_df = pd.read_csv('regret_1_sim.csv')

participants_df['omega'] = participants_df.apply(lambda row: 0 if row['condition'] == 'control' else row['omega'], axis=1)

# exclude participant 797
participants_df = participants_df[participants_df['participant'] != 797]
participants_df = participants_df[participants_df['participant'] != 881]

participants_df.head()
# Out:
#    participant    condition     omega       tau        nll
# 0          860  regret_late  0.378480  0.357759  28.756001
# 1          835  regret_late  0.125176  0.209758  18.831045
# 2          753  regret_late  0.501065  0.690517  33.319092
# 3          833  regret_late  0.478296  0.584262  32.419643
# 4          841  regret_late  0.334865  0.992489  34.548622

# %% [markdown]
# ## GiG

# %%
num_trees = 3
num_trials = 60 
tree_probs = [0.7, 0.5, 0.2] 

tree_probabilities = {i: prob for i, prob in enumerate(tree_probs)}

sorted_trees = sorted(tree_probabilities, key=tree_probabilities.get, reverse=True)
best_tree = sorted_trees[0]    # index of the best tree
medium_tree = sorted_trees[1]  # index of the medium tree
worst_tree = sorted_trees[2]   # index of the worst tree

all_data = []

# -----------------------
# Loop over each participant
# -----------------------
for idx, row in participants_df.iterrows():
    
    participant_id = row['participant']
    temperature = row['tau']            
    counterfactual_weight = row['omega'] 
    condition = row['condition']       
    
    num_simulations = 100
    
    for sim_id in range(num_simulations):
        tree_beliefs = np.ones(num_trees) / num_trees  # initial beliefs
        alpha = np.ones(num_trees)  # prior alpha for Beta distribution
        beta = np.ones(num_trees)   # prior beta for Beta distribution
        points = np.zeros(num_trials)
        
        # Run RL agent for the specified number of trials
        for trial in range(num_trials):
            exp_values = np.exp(tree_beliefs / temperature)
            softmax_values = exp_values / np.sum(exp_values)
            
            # select action based on the softmax probabilities
            action = np.random.choice(np.arange(num_trees), p=softmax_values)
            
            # simulate outcome of the chosen tree
            outcome = np.random.choice([0, 1], p=[1 - tree_probs[action], tree_probs[action]])
            points[trial] = outcome

            # GiG updating
            if (condition == 'regret_early' and trial <= 30):
                if outcome == 0:
                    for tree in range(num_trees):
                        if tree != action:
                            alpha[tree] += counterfactual_weight

            if (condition == 'regret_late' and trial > 30):
                if outcome == 0:
                    for tree in range(num_trees):
                        if tree != action:
                            alpha[tree] += counterfactual_weight
            
            # Update alpha/beta for the chosen tree based on the actual outcome
            if outcome == 1:
                alpha[action] += 1
            else:
                beta[action] += 1

            for tree in range(num_trees):
                successes = alpha[tree]
                failures = beta[tree]
                tree_beliefs[tree] = successes / (successes + failures)
            
            if action == best_tree:
                choice_goodbad = 'best'
            elif action == medium_tree:
                choice_goodbad = 'medium'
            else:
                choice_goodbad = 'worst'

            all_data.append({
                'participant': participant_id,
                'tau': temperature,
                'omega': row['omega'],
                'trial_index': trial,
                'points': points[trial],
                'choice_goodbad': choice_goodbad,
                'condition': f'regret_{condition}' 
            })

# -----------------------
# Convert to DataFrame and Save
# -----------------------
df_all = pd.DataFrame(all_data)

df_all = df_all[['participant', 'tau', 'omega', 'trial_index',
                 'points', 'choice_goodbad', 'condition']]

df_all.to_csv('simulation_output_all_participants.csv', index=False)

# %% [markdown]
# ## Null

# %%
num_trees = 3
num_trials = 60  
tree_probs = [0.7, 0.5, 0.2]  

tree_probabilities = {i: prob for i, prob in enumerate(tree_probs)}

sorted_trees = sorted(tree_probabilities, key=tree_probabilities.get, reverse=True)
best_tree = sorted_trees[0]    # index of the best tree
medium_tree = sorted_trees[1]  # index of the medium tree
worst_tree = sorted_trees[2]   # index of the worst tree

all_data = []

# -----------------------
# Loop over each participant
# -----------------------
for idx, row in participants_df.iterrows():
    
    participant_id = row['participant']
    temperature = row['tau']
    condition = row['condition']    
    
    num_simulations = 100
    
    for sim_id in range(num_simulations):
        tree_beliefs = np.ones(num_trees) / num_trees  # initial beliefs
        alpha = np.ones(num_trees)  # prior alpha for Beta distribution
        beta = np.ones(num_trees)   # prior beta for Beta distribution
        points = np.zeros(num_trials)
        
        # Run RL agent for the specified number of trials
        for trial in range(num_trials):
            exp_values = np.exp(tree_beliefs / temperature)
            softmax_values = exp_values / np.sum(exp_values)
            
            # Select action based on the softmax probabilities
            action = np.random.choice(np.arange(num_trees), p=softmax_values)
            
            # Simulate outcome of the chosen tree
            outcome = np.random.choice([0, 1], p=[1 - tree_probs[action], tree_probs[action]])
            points[trial] = outcome
            
            # Update alpha/beta for the chosen tree based on the actual outcome
            if outcome == 1:
                alpha[action] += 1
            else:
                beta[action] += 1
            
            for tree in range(num_trees):
                successes = alpha[tree]
                failures = beta[tree]
                tree_beliefs[tree] = successes / (successes + failures)
            
            if action == best_tree:
                choice_goodbad = 'best'
            elif action == medium_tree:
                choice_goodbad = 'medium'
            else:
                choice_goodbad = 'worst'
            
            all_data.append({
                'participant': participant_id,
                'tau': temperature,
                'omega': row['omega'],
                'trial_index': trial,
                'points': points[trial],
                'choice_goodbad': choice_goodbad,
                'condition': condition  
            })
# -----------------------
# Convert to DataFrame and Save
# -----------------------
df_all = pd.DataFrame(all_data)

df_all = df_all[['participant', 'tau', 'omega', 'trial_index',
                 'points', 'choice_goodbad', 'condition']]

df_all.to_csv('simulation_output_all_participants_null.csv', index=False)

# %% [markdown]
# ## CS

# %%
participants_df = pd.read_csv('cf_1_sim.csv')

participants_df['omega'] = participants_df.apply(lambda row: 0 if row['condition'] == 'control' else row['omega'], axis=1)

participants_df = participants_df[participants_df['participant'] != 797]
participants_df = participants_df[participants_df['participant'] != 881]

participants_df.head()
# Out:
#    participant    condition     omega       tau        nll
# 0          860  regret_late  0.241443  0.206786  27.613682
# 1          835  regret_late  0.049607  0.030124   2.631860
# 2          753  regret_late  4.646651  1.325840  32.893864
# 3          833  regret_late  0.132556  0.480181  32.321712
# 4          841  regret_late  0.032136  1.405803  32.961685

# %%
num_trees = 3
num_trials = 60 
tree_probs = [0.7, 0.5, 0.2] 

tree_probabilities = {i: prob for i, prob in enumerate(tree_probs)}

sorted_trees = sorted(tree_probabilities, key=tree_probabilities.get, reverse=True)
best_tree = sorted_trees[0]    # index of the best tree
medium_tree = sorted_trees[1]  # index of the medium tree
worst_tree = sorted_trees[2]   # index of the worst tree

all_data = []

# -----------------------
# Loop over each participant
# -----------------------
for idx, row in participants_df.iterrows():
    
    participant_id = row['participant']
    temperature = row['tau']    
    counterfactual_weight = row['omega'] 
    condition = row['condition']       
    
    num_simulations = 100
    
    for sim_id in range(num_simulations):
        tree_beliefs = np.ones(num_trees) / num_trees  # initial beliefs
        alpha = np.ones(num_trees)  # prior alpha for Beta distribution
        beta = np.ones(num_trees)   # prior beta for Beta distribution
        points = np.zeros(num_trials)
        
        # Run RL agent for the specified number of trials
        for trial in range(num_trials):
            exp_values = np.exp(tree_beliefs / temperature)
            softmax_values = exp_values / np.sum(exp_values)
            
            # Select action based on softmax probabilities
            action = np.random.choice(np.arange(num_trees), p=softmax_values)
            
            # Simulate outcome of the chosen tree
            outcome = np.random.choice([0, 1], p=[1 - tree_probs[action], tree_probs[action]])
            points[trial] = outcome
            
            # CS updating
            if condition == "regret_early" and trial <= 30 and outcome == 0:
                for tree in range(num_trees):
                    if tree != action:
                        # Initialize a counterfactual outcome vector and simulate for this tree based on beliefs
                        counterfactual_outcome = np.zeros(num_trees)
                        counterfactual_outcome[tree] = np.random.choice(
                            [0, 1], p=[1 - tree_beliefs[tree], tree_beliefs[tree]]
                        )
                        if counterfactual_outcome[tree] == 1:
                            alpha[tree] += counterfactual_weight
                        else:
                            beta[tree] += counterfactual_weight

            if condition == "regret_late" and trial > 30 and outcome == 0:
                for tree in range(num_trees):
                    if tree != action:
                        # Initialize a counterfactual outcome vector and simulate for this tree based on beliefs
                        counterfactual_outcome = np.zeros(num_trees)
                        counterfactual_outcome[tree] = np.random.choice(
                            [0, 1], p=[1 - tree_beliefs[tree], tree_beliefs[tree]]
                        )
                        if counterfactual_outcome[tree] == 1:
                            alpha[tree] += counterfactual_weight
                        else:
                            beta[tree] += counterfactual_weight
            
            # Update alpha/beta for the chosen tree based on the actual outcome
            if outcome == 1:
                alpha[action] += 1
            else:
                beta[action] += 1

            for tree in range(num_trees):
                successes = alpha[tree]
                failures = beta[tree]
                tree_beliefs[tree] = successes / (successes + failures)
            
            if action == best_tree:
                choice_goodbad = 'best'
            elif action == medium_tree:
                choice_goodbad = 'medium'
            else:
                choice_goodbad = 'worst'
            
            all_data.append({
                'participant': participant_id,
                'tau': temperature,
                'omega': row['omega'],
                'trial_index': trial,
                'points': points[trial],
                'choice_goodbad': choice_goodbad,
                'condition': f'regret_{condition}'
            })

# -----------------------
# Convert to DataFrame and Save
# -----------------------
df_all = pd.DataFrame(all_data)

df_all = df_all[['participant', 'tau', 'omega', 'trial_index',
                 'points', 'choice_goodbad', 'condition']]

df_all.to_csv('cf_simulation_output_all_participants.csv', index=False)
